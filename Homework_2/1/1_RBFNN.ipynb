# %%
# -*- coding: utf-8 -*-

"""
Created on Thu Oct 17 18:33:06 2019

@author: steve
"""
# Out:
# '\nCreated on Thu Oct 17 18:33:06 2019\n\n@author: steve\n'

# %%
# rbf layer from https://github.com/PetraVidnerova/rbf_keras

from keras import backend as K
# from keras.engine.topology import Layer
from keras.layers import Layer
from keras.initializers import RandomUniform, Initializer, Constant
import numpy as np

# %%
class InitCentersRandom(Initializer):
    """ Initializer for initialization of centers of RBF network
        as random samples from the given data set.
    # Arguments
        X: matrix, dataset to choose the centers from (random rows
          are taken as centers)
    """

    def __init__(self, X):
        self.X = X

    def __call__(self, shape, dtype=None):
        assert shape[1] == self.X.shape[1]
        idx = np.random.randint(self.X.shape[0], size=shape[0])
        return self.X[idx, :]


class RBFLayer(Layer):
    """ Layer of Gaussian RBF units.
    # Example
    ```python
        model = Sequential()
        model.add(RBFLayer(10,
                           initializer=InitCentersRandom(X),
                           betas=1.0,
                           input_shape=(1,)))
        model.add(Dense(1))
    ```
    # Arguments
        output_dim: number of hidden units (i.e. number of outputs of the
                    layer)
        initializer: instance of initiliazer to initialize centers
        betas: float, initial value for betas
    """

    def __init__(self, output_dim, initializer=None, betas=1.0, **kwargs):
        self.output_dim = output_dim
        self.init_betas = betas
        if not initializer:
            self.initializer = RandomUniform(0.0, 1.0)
        else:
            self.initializer = initializer
        super(RBFLayer, self).__init__(**kwargs)

    def build(self, input_shape):

        self.centers = self.add_weight(name='centers',
                                       shape=(self.output_dim, input_shape[1]),
                                       initializer=self.initializer,
                                       trainable=True)
        self.betas = self.add_weight(name='betas',
                                     shape=(self.output_dim,),
                                     initializer=Constant(
                                         value=self.init_betas),
                                     # initializer='ones',
                                     trainable=True)

        super(RBFLayer, self).build(input_shape)

    def call(self, x):

        C = K.expand_dims(self.centers)
        H = K.transpose(C-K.transpose(x))
        return K.exp(-self.betas * K.sum(H**2, axis=1))

        # C = self.centers[np.newaxis, :, :]
        # X = x[:, np.newaxis, :]

        # diffnorm = K.sum((C-X)**2, axis=-1)
        # ret = K.exp( - self.betas * diffnorm)
        # return ret

    def compute_output_shape(self, input_shape):
        return (input_shape[0], self.output_dim)

    def get_config(self):
        # have to define get_config to be able to use model_from_json
        config = {
            'output_dim': self.output_dim
        }
        base_config = super(RBFLayer, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %% [markdown]
# ### read input & output data

# %%
import pandas as pd #與Panel、DataFrame 與 Series 相呼應

#read input & output data
x_train=open("../dataset/MackeyGlass/train_X.txt")
x_train=pd.read_csv(x_train, sep="\t",header=0)
y_train=open("../dataset/MackeyGlass/train_y.txt")
y_train=(pd.read_csv(y_train, sep="\t",header=0)).iloc[:,1]

x_test=open("../dataset/MackeyGlass/test_X.txt")
x_test=pd.read_csv(x_test, sep="\t",header=0)
y_test=open("../dataset/MackeyGlass/test_Y.txt")
y_test=(pd.read_csv(y_test, sep="\t",header=0)).iloc[:,1]

# %% [markdown]
# ### using input label

# %%
data_in=x_train
data_real_out=y_train
test_in=x_test
test_real_out=y_test

# %% [markdown]
# ### data normalization

# %%
data_in_max=data_in.max()
data_in_min=data_in.min()
data_in_norm=(data_in-data_in_min)/(data_in_max-data_in_min)
data_in_norm=np.asarray(data_in_norm)

data_real_out_max=data_real_out.max()
data_real_out_min=data_real_out.min()
data_real_out_norm=(data_real_out-data_real_out_min)/(data_real_out_max-data_real_out_min)
data_real_out_norm=np.asarray(data_real_out_norm)

test_in_max=test_in.max()
test_in_min=test_in.min()
test_in_norm=(test_in-test_in_min)/(test_in_max-test_in_min)
test_in_norm=np.asarray(test_in_norm)

test_real_out_max=test_real_out.max()
test_real_out_min=test_real_out.min()
test_real_out_norm=(test_real_out-test_real_out_min)/(test_real_out_max-test_real_out_min)
test_real_out_norm=np.asarray(test_real_out_norm)

# %% [markdown]
# ### Build Model

# %%
#define error function & calculate model's output error
def np_RMSE(output,output_pred):
    rmserror=0
    for i in range(len(output)):
        rmserror=rmserror+np.square(output[i]-output_pred[i])
    rmserror=np.sqrt(rmserror/len(output))
    return rmserror

def np_R2(output,output_pred):
    return np.square(np.corrcoef(output.reshape(np.size(output)),output_pred.reshape(np.size(output_pred)), False)[1,0])

# %% [markdown]
# #### 1-b. 以交叉驗證方式訓練BPNN模式，列初步同分組組合之RMSE與$R^2$值

# %%
from keras.models import Sequential,load_model
from keras import backend as K
from keras.layers import Dense
from keras.layers.core import Activation
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.optimizers import adam_v2
#from keras.layers.normalization import BatchNormalization
from sklearn.model_selection import KFold
from keras.callbacks import History
from keras.metrics import mean_squared_error as mserr

history = History()

RMSE_history_list = []
R2_history_list = []
seed = 7
best_RMSE = np.inf
kfold = KFold(n_splits=3, shuffle=False)
for train, validation in kfold.split(data_in_norm, data_real_out_norm):

    K.clear_session()
    # 模型結構
    model = Sequential()
    model.add(RBFLayer(5,initializer=InitCentersRandom(data_in_norm),betas=1.0,input_shape=(len(data_in_norm[0]),)))
    model.add(Activation('tanh'))
    model.add(Dense(1))

    # 模型相關設定
    learning_rate=1e-4 #設定學習速率
    adam = adam_v2.Adam(lr=learning_rate) #設定的優化器
    model.compile(optimizer=adam,loss="mse") #執行設定好的優化器和誤差函數
    # earlystopper = EarlyStopping(monitor='val_loss', patience=10, verbose=0) #設定early stopping的參數
    # checkpoint =ModelCheckpoint("rbf-model.hdf5",save_best_only=True)
    #每次迭代儲存模式，我設定了最終只儲存最佳的模式(當驗證誤差最小的時候)
    # callback_list=[earlystopper,checkpoint]
    model.fit(data_in_norm,data_real_out_norm,
              epochs=200, batch_size=8, validation_split=0.2, workers=8
              # callbacks=callback_list
              )

    prediction = np.squeeze(model.predict(data_in_norm[validation]))
    current_RMSE = np_RMSE(prediction, data_real_out_norm[validation])
    current_R2 = np_R2(prediction, data_real_out_norm[validation])
    RMSE_history_list.append(current_RMSE)
    R2_history_list.append(current_R2)

    if (current_RMSE < best_RMSE):
        best_RMSE = current_RMSE
        model.save("rbf-model.hdf5")
        print(f'best model updated!')
    #執行模式訓練并且把設定好的early stopping以及儲存模式參數套用到訓練中

#more details reference: https://keras.io/
# Out:
# Epoch 1/200
#  1/50 [..............................] - ETA: 7s - loss: 0.1296
# C:\Users\woody\AppData\Roaming\Python\Python38\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1000 - val_loss: 0.0480
# Epoch 2/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0855 - val_loss: 0.0413
# Epoch 3/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0737 - val_loss: 0.0362
# Epoch 4/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0639 - val_loss: 0.0325
# Epoch 5/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0561 - val_loss: 0.0298
# Epoch 6/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0496 - val_loss: 0.0281
# Epoch 7/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0445 - val_loss: 0.0270
# Epoch 8/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0404 - val_loss: 0.0263
# Epoch 9/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0372 - val_loss: 0.0261
# Epoch 10/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0345 - val_loss: 0.0259
# Epoch 11/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0324 - val_loss: 0.0259
# Epoch 12/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0305 - val_loss: 0.0258
# Epoch 13/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0290 - val_loss: 0.0260
# Epoch 14/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0277 - val_loss: 0.0259
# Epoch 15/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0266 - val_loss: 0.0257
# Epoch 16/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0256 - val_loss: 0.0257
# Epoch 17/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0247 - val_loss: 0.0254
# Epoch 18/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0238 - val_loss: 0.0252
# Epoch 19/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0231 - val_loss: 0.0248
# Epoch 20/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0223 - val_loss: 0.0247
# Epoch 21/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0216 - val_loss: 0.0244
# Epoch 22/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0210 - val_loss: 0.0239
# Epoch 23/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0204 - val_loss: 0.0237
# Epoch 24/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0198 - val_loss: 0.0232
# Epoch 25/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0193 - val_loss: 0.0231
# Epoch 26/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0188 - val_loss: 0.0226
# Epoch 27/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0183 - val_loss: 0.0225
# Epoch 28/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0179 - val_loss: 0.0222
# Epoch 29/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0175 - val_loss: 0.0220
# Epoch 30/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0171 - val_loss: 0.0217
# Epoch 31/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0167 - val_loss: 0.0214
# Epoch 32/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0164 - val_loss: 0.0210
# Epoch 33/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0161 - val_loss: 0.0209
# Epoch 34/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0158 - val_loss: 0.0207
# Epoch 35/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0155 - val_loss: 0.0205
# Epoch 36/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0153 - val_loss: 0.0203
# Epoch 37/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0150 - val_loss: 0.0201
# Epoch 38/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0148 - val_loss: 0.0200
# Epoch 39/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0146 - val_loss: 0.0200
# Epoch 40/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0144 - val_loss: 0.0198
# Epoch 41/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0142 - val_loss: 0.0195
# Epoch 42/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0140 - val_loss: 0.0193
# Epoch 43/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0139 - val_loss: 0.0193
# Epoch 44/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0137 - val_loss: 0.0191
# Epoch 45/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0136 - val_loss: 0.0191
# Epoch 46/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0134 - val_loss: 0.0190
# Epoch 47/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0133 - val_loss: 0.0188
# Epoch 48/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0132 - val_loss: 0.0187
# Epoch 49/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0131 - val_loss: 0.0188
# Epoch 50/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0130 - val_loss: 0.0185
# Epoch 51/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0129 - val_loss: 0.0184
# Epoch 52/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0128 - val_loss: 0.0184
# Epoch 53/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0127 - val_loss: 0.0182
# Epoch 54/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0126 - val_loss: 0.0181
# Epoch 55/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0125 - val_loss: 0.0181
# Epoch 56/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0124 - val_loss: 0.0180
# Epoch 57/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0123 - val_loss: 0.0179
# Epoch 58/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0122 - val_loss: 0.0178
# Epoch 59/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0122 - val_loss: 0.0178
# Epoch 60/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0121 - val_loss: 0.0175
# Epoch 61/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0120 - val_loss: 0.0177
# Epoch 62/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0119 - val_loss: 0.0174
# Epoch 63/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0118 - val_loss: 0.0174
# Epoch 64/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0118 - val_loss: 0.0173
# Epoch 65/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0117 - val_loss: 0.0173
# Epoch 66/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0116 - val_loss: 0.0172
# Epoch 67/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0116 - val_loss: 0.0171
# Epoch 68/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0115 - val_loss: 0.0171
# Epoch 69/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0114 - val_loss: 0.0170
# Epoch 70/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0113 - val_loss: 0.0168
# Epoch 71/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0113 - val_loss: 0.0168
# Epoch 72/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0112 - val_loss: 0.0167
# Epoch 73/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0111 - val_loss: 0.0167
# Epoch 74/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0111 - val_loss: 0.0165
# Epoch 75/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0110 - val_loss: 0.0165
# Epoch 76/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0109 - val_loss: 0.0164
# Epoch 77/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0109 - val_loss: 0.0164
# Epoch 78/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0108 - val_loss: 0.0162
# Epoch 79/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0107 - val_loss: 0.0162
# Epoch 80/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0107 - val_loss: 0.0163
# Epoch 81/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0106 - val_loss: 0.0158
# Epoch 82/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0106 - val_loss: 0.0162
# Epoch 83/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0105 - val_loss: 0.0161
# Epoch 84/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0104 - val_loss: 0.0158
# Epoch 85/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0103 - val_loss: 0.0158
# Epoch 86/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0103 - val_loss: 0.0158
# Epoch 87/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0102 - val_loss: 0.0158
# Epoch 88/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0101 - val_loss: 0.0157
# Epoch 89/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0101 - val_loss: 0.0157
# Epoch 90/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0101 - val_loss: 0.0154
# Epoch 91/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0100 - val_loss: 0.0155
# Epoch 92/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0099 - val_loss: 0.0156
# Epoch 93/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0098 - val_loss: 0.0154
# Epoch 94/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0098 - val_loss: 0.0155
# Epoch 95/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0097 - val_loss: 0.0153
# Epoch 96/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0096 - val_loss: 0.0151
# Epoch 97/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0096 - val_loss: 0.0152
# Epoch 98/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0095 - val_loss: 0.0152
# Epoch 99/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0095 - val_loss: 0.0152
# Epoch 100/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0094 - val_loss: 0.0151
# Epoch 101/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0093 - val_loss: 0.0149
# Epoch 102/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0093 - val_loss: 0.0149
# Epoch 103/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0092 - val_loss: 0.0150
# Epoch 104/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0091 - val_loss: 0.0149
# Epoch 105/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0091 - val_loss: 0.0149
# Epoch 106/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0090 - val_loss: 0.0146
# Epoch 107/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0090 - val_loss: 0.0146
# Epoch 108/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0089 - val_loss: 0.0144
# Epoch 109/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0088 - val_loss: 0.0148
# Epoch 110/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0088 - val_loss: 0.0147
# Epoch 111/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0087 - val_loss: 0.0146
# Epoch 112/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0087 - val_loss: 0.0145
# Epoch 113/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0086 - val_loss: 0.0145
# Epoch 114/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0085 - val_loss: 0.0143
# Epoch 115/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0085 - val_loss: 0.0144
# Epoch 116/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0084 - val_loss: 0.0143
# Epoch 117/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0084 - val_loss: 0.0142
# Epoch 118/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0083 - val_loss: 0.0143
# Epoch 119/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0083 - val_loss: 0.0144
# Epoch 120/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0082 - val_loss: 0.0139
# Epoch 121/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0082 - val_loss: 0.0141
# Epoch 122/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0081 - val_loss: 0.0140
# Epoch 123/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0080 - val_loss: 0.0142
# Epoch 124/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0080 - val_loss: 0.0141
# Epoch 125/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0079 - val_loss: 0.0140
# Epoch 126/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0079 - val_loss: 0.0142
# Epoch 127/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0078 - val_loss: 0.0138
# Epoch 128/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0078 - val_loss: 0.0140
# Epoch 129/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0077 - val_loss: 0.0138
# Epoch 130/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0077 - val_loss: 0.0137
# Epoch 131/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0076 - val_loss: 0.0137
# Epoch 132/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0076 - val_loss: 0.0137
# Epoch 133/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0075 - val_loss: 0.0138
# Epoch 134/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0074 - val_loss: 0.0136
# Epoch 135/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0074 - val_loss: 0.0136
# Epoch 136/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0074 - val_loss: 0.0136
# Epoch 137/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0073 - val_loss: 0.0135
# Epoch 138/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0072 - val_loss: 0.0135
# Epoch 139/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0072 - val_loss: 0.0135
# Epoch 140/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.0136
# Epoch 141/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.0135
# Epoch 142/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.0136
# Epoch 143/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0070 - val_loss: 0.0134
# Epoch 144/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0069 - val_loss: 0.0135
# Epoch 145/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0069 - val_loss: 0.0133
# Epoch 146/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0132
# Epoch 147/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0132
# Epoch 148/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0132
# Epoch 149/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.0132
# Epoch 150/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.0134
# Epoch 151/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.0129
# Epoch 152/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.0131
# Epoch 153/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.0131
# Epoch 154/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.0131
# Epoch 155/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0129
# Epoch 156/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0130
# Epoch 157/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0129
# Epoch 158/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0128
# Epoch 159/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0130
# Epoch 160/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0130
# Epoch 161/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0127
# Epoch 162/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.0128
# Epoch 163/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.0128
# Epoch 164/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0128
# Epoch 165/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0128
# Epoch 166/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0129
# Epoch 167/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0128
# Epoch 168/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0125
# Epoch 169/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0127
# Epoch 170/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0126
# Epoch 171/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.0127
# Epoch 172/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.0126
# Epoch 173/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.0123
# Epoch 174/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0126
# Epoch 175/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0124
# Epoch 176/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0126
# Epoch 177/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0125
# Epoch 178/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0126
# Epoch 179/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0121
# Epoch 180/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.0124
# Epoch 181/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.0125
# Epoch 182/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0125
# Epoch 183/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0123
# Epoch 184/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0125
# Epoch 185/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0122
# Epoch 186/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0124
# Epoch 187/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0124
# Epoch 188/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0122
# Epoch 189/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0123
# Epoch 190/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0121
# Epoch 191/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0121
# Epoch 192/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 0.0123
# Epoch 193/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 0.0122
# Epoch 194/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 0.0121
# Epoch 195/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0121
# Epoch 196/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0119
# Epoch 197/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0120
# Epoch 198/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0119
# Epoch 199/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0120
# Epoch 200/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0120
# best model updated!
# Epoch 1/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.9782 - val_loss: 0.9667
# Epoch 2/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.9239 - val_loss: 0.9198
# Epoch 3/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.8719 - val_loss: 0.8737
# Epoch 4/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.8225 - val_loss: 0.8303
# Epoch 5/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7754 - val_loss: 0.7887
# Epoch 6/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7305 - val_loss: 0.7489
# Epoch 7/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6878 - val_loss: 0.7111
# Epoch 8/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6473 - val_loss: 0.6748
# Epoch 9/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6087 - val_loss: 0.6401
# Epoch 10/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5722 - val_loss: 0.6070
# Epoch 11/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5374 - val_loss: 0.5756
# Epoch 12/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5045 - val_loss: 0.5453
# Epoch 13/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4733 - val_loss: 0.5168
# Epoch 14/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4439 - val_loss: 0.4893
# Epoch 15/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4160 - val_loss: 0.4634
# Epoch 16/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3897 - val_loss: 0.4386
# Epoch 17/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3649 - val_loss: 0.4150
# Epoch 18/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3414 - val_loss: 0.3928
# Epoch 19/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3193 - val_loss: 0.3716
# Epoch 20/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2985 - val_loss: 0.3515
# Epoch 21/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2790 - val_loss: 0.3322
# Epoch 22/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2606 - val_loss: 0.3140
# Epoch 23/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2434 - val_loss: 0.2967
# Epoch 24/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2271 - val_loss: 0.2807
# Epoch 25/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2120 - val_loss: 0.2651
# Epoch 26/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1977 - val_loss: 0.2505
# Epoch 27/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1844 - val_loss: 0.2369
# Epoch 28/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1721 - val_loss: 0.2237
# Epoch 29/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1604 - val_loss: 0.2115
# Epoch 30/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1496 - val_loss: 0.2000
# Epoch 31/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1396 - val_loss: 0.1890
# Epoch 32/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1302 - val_loss: 0.1785
# Epoch 33/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1215 - val_loss: 0.1689
# Epoch 34/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1134 - val_loss: 0.1597
# Epoch 35/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1060 - val_loss: 0.1510
# Epoch 36/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0990 - val_loss: 0.1429
# Epoch 37/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0926 - val_loss: 0.1354
# Epoch 38/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0866 - val_loss: 0.1282
# Epoch 39/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0812 - val_loss: 0.1215
# Epoch 40/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0761 - val_loss: 0.1151
# Epoch 41/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0714 - val_loss: 0.1092
# Epoch 42/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0671 - val_loss: 0.1037
# Epoch 43/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0632 - val_loss: 0.0984
# Epoch 44/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0595 - val_loss: 0.0936
# Epoch 45/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0562 - val_loss: 0.0888
# Epoch 46/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0531 - val_loss: 0.0846
# Epoch 47/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0503 - val_loss: 0.0806
# Epoch 48/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0477 - val_loss: 0.0769
# Epoch 49/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0453 - val_loss: 0.0733
# Epoch 50/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0431 - val_loss: 0.0700
# Epoch 51/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0411 - val_loss: 0.0669
# Epoch 52/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0393 - val_loss: 0.0640
# Epoch 53/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0376 - val_loss: 0.0613
# Epoch 54/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0360 - val_loss: 0.0588
# Epoch 55/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0346 - val_loss: 0.0563
# Epoch 56/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0333 - val_loss: 0.0541
# Epoch 57/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0320 - val_loss: 0.0520
# Epoch 58/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0309 - val_loss: 0.0500
# Epoch 59/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0299 - val_loss: 0.0481
# Epoch 60/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0289 - val_loss: 0.0464
# Epoch 61/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0280 - val_loss: 0.0447
# Epoch 62/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0271 - val_loss: 0.0432
# Epoch 63/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0263 - val_loss: 0.0416
# Epoch 64/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0256 - val_loss: 0.0403
# Epoch 65/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0249 - val_loss: 0.0390
# Epoch 66/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0242 - val_loss: 0.0378
# Epoch 67/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0236 - val_loss: 0.0365
# Epoch 68/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0230 - val_loss: 0.0354
# Epoch 69/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0224 - val_loss: 0.0343
# Epoch 70/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0219 - val_loss: 0.0333
# Epoch 71/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0214 - val_loss: 0.0324
# Epoch 72/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0209 - val_loss: 0.0315
# Epoch 73/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0204 - val_loss: 0.0306
# Epoch 74/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0199 - val_loss: 0.0298
# Epoch 75/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0195 - val_loss: 0.0290
# Epoch 76/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0191 - val_loss: 0.0283
# Epoch 77/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0187 - val_loss: 0.0275
# Epoch 78/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0183 - val_loss: 0.0268
# Epoch 79/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0179 - val_loss: 0.0261
# Epoch 80/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0175 - val_loss: 0.0255
# Epoch 81/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0172 - val_loss: 0.0249
# Epoch 82/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0168 - val_loss: 0.0244
# Epoch 83/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0165 - val_loss: 0.0238
# Epoch 84/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0162 - val_loss: 0.0231
# Epoch 85/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0158 - val_loss: 0.0227
# Epoch 86/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0155 - val_loss: 0.0222
# Epoch 87/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0152 - val_loss: 0.0217
# Epoch 88/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0150 - val_loss: 0.0211
# Epoch 89/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0147 - val_loss: 0.0207
# Epoch 90/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0144 - val_loss: 0.0203
# Epoch 91/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0142 - val_loss: 0.0198
# Epoch 92/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0139 - val_loss: 0.0194
# Epoch 93/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0137 - val_loss: 0.0190
# Epoch 94/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0135 - val_loss: 0.0186
# Epoch 95/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0133 - val_loss: 0.0182
# Epoch 96/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0131 - val_loss: 0.0179
# Epoch 97/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0129 - val_loss: 0.0175
# Epoch 98/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0127 - val_loss: 0.0171
# Epoch 99/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0125 - val_loss: 0.0168
# Epoch 100/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0123 - val_loss: 0.0164
# Epoch 101/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0121 - val_loss: 0.0163
# Epoch 102/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0120 - val_loss: 0.0159
# Epoch 103/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0118 - val_loss: 0.0156
# Epoch 104/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0117 - val_loss: 0.0153
# Epoch 105/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0115 - val_loss: 0.0150
# Epoch 106/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0114 - val_loss: 0.0148
# Epoch 107/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0112 - val_loss: 0.0145
# Epoch 108/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0111 - val_loss: 0.0143
# Epoch 109/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0110 - val_loss: 0.0140
# Epoch 110/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0109 - val_loss: 0.0138
# Epoch 111/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0107 - val_loss: 0.0136
# Epoch 112/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0106 - val_loss: 0.0134
# Epoch 113/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0105 - val_loss: 0.0132
# Epoch 114/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0104 - val_loss: 0.0130
# Epoch 115/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0103 - val_loss: 0.0127
# Epoch 116/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0102 - val_loss: 0.0126
# Epoch 117/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0101 - val_loss: 0.0124
# Epoch 118/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0100 - val_loss: 0.0122
# Epoch 119/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0100 - val_loss: 0.0120
# Epoch 120/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0099 - val_loss: 0.0118
# Epoch 121/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0098 - val_loss: 0.0117
# Epoch 122/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0097 - val_loss: 0.0116
# Epoch 123/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0097 - val_loss: 0.0113
# Epoch 124/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0096 - val_loss: 0.0113
# Epoch 125/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0095 - val_loss: 0.0111
# Epoch 126/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0094 - val_loss: 0.0110
# Epoch 127/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0094 - val_loss: 0.0108
# Epoch 128/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0093 - val_loss: 0.0107
# Epoch 129/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0092 - val_loss: 0.0105
# Epoch 130/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0092 - val_loss: 0.0105
# Epoch 131/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0091 - val_loss: 0.0103
# Epoch 132/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0091 - val_loss: 0.0102
# Epoch 133/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0090 - val_loss: 0.0100
# Epoch 134/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0089 - val_loss: 0.0100
# Epoch 135/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0089 - val_loss: 0.0099
# Epoch 136/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0088 - val_loss: 0.0097
# Epoch 137/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0088 - val_loss: 0.0096
# Epoch 138/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0087 - val_loss: 0.0096
# Epoch 139/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0087 - val_loss: 0.0094
# Epoch 140/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0086 - val_loss: 0.0093
# Epoch 141/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0085 - val_loss: 0.0092
# Epoch 142/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0085 - val_loss: 0.0092
# Epoch 143/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0084 - val_loss: 0.0091
# Epoch 144/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0084 - val_loss: 0.0090
# Epoch 145/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0083 - val_loss: 0.0089
# Epoch 146/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0083 - val_loss: 0.0089
# Epoch 147/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0082 - val_loss: 0.0088
# Epoch 148/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0081 - val_loss: 0.0087
# Epoch 149/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0081 - val_loss: 0.0087
# Epoch 150/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0080 - val_loss: 0.0086
# Epoch 151/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0080 - val_loss: 0.0084
# Epoch 152/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0079 - val_loss: 0.0085
# Epoch 153/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0079 - val_loss: 0.0083
# Epoch 154/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0078 - val_loss: 0.0083
# Epoch 155/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0078 - val_loss: 0.0082
# Epoch 156/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0077 - val_loss: 0.0082
# Epoch 157/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0077 - val_loss: 0.0081
# Epoch 158/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0076 - val_loss: 0.0080
# Epoch 159/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0076 - val_loss: 0.0080
# Epoch 160/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0075 - val_loss: 0.0079
# Epoch 161/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0074 - val_loss: 0.0078
# Epoch 162/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0074 - val_loss: 0.0078
# Epoch 163/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0073 - val_loss: 0.0078
# Epoch 164/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0073 - val_loss: 0.0077
# Epoch 165/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0072 - val_loss: 0.0076
# Epoch 166/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0072 - val_loss: 0.0075
# Epoch 167/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.0076
# Epoch 168/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.0075
# Epoch 169/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0070 - val_loss: 0.0074
# Epoch 170/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0070 - val_loss: 0.0074
# Epoch 171/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0069 - val_loss: 0.0073
# Epoch 172/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0073
# Epoch 173/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0073
# Epoch 174/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.0072
# Epoch 175/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.0071
# Epoch 176/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.0070
# Epoch 177/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.0071
# Epoch 178/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.0070
# Epoch 179/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.0069
# Epoch 180/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0069
# Epoch 181/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0068
# Epoch 182/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0068
# Epoch 183/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0068
# Epoch 184/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0067
# Epoch 185/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0067
# Epoch 186/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.0067
# Epoch 187/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.0066
# Epoch 188/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0066
# Epoch 189/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0066
# Epoch 190/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0065
# Epoch 191/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0065
# Epoch 192/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0064
# Epoch 193/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0064
# Epoch 194/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.0064
# Epoch 195/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.0064
# Epoch 196/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0063
# Epoch 197/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0063
# Epoch 198/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0062
# Epoch 199/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0062
# Epoch 200/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.0062
# Epoch 1/200
# 50/50 [==============================] - 0s 3ms/step - loss: 1.2660 - val_loss: 0.8789
# Epoch 2/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.2040 - val_loss: 0.8339
# Epoch 3/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.1451 - val_loss: 0.7909
# Epoch 4/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.0885 - val_loss: 0.7505
# Epoch 5/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.0346 - val_loss: 0.7116
# Epoch 6/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.9830 - val_loss: 0.6745
# Epoch 7/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.9339 - val_loss: 0.6395
# Epoch 8/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.8871 - val_loss: 0.6061
# Epoch 9/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.8425 - val_loss: 0.5744
# Epoch 10/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.8000 - val_loss: 0.5442
# Epoch 11/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7596 - val_loss: 0.5155
# Epoch 12/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7211 - val_loss: 0.4883
# Epoch 13/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6844 - val_loss: 0.4627
# Epoch 14/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6496 - val_loss: 0.4383
# Epoch 15/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6166 - val_loss: 0.4149
# Epoch 16/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5851 - val_loss: 0.3928
# Epoch 17/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5552 - val_loss: 0.3720
# Epoch 18/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5268 - val_loss: 0.3523
# Epoch 19/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5000 - val_loss: 0.3336
# Epoch 20/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4744 - val_loss: 0.3158
# Epoch 21/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4502 - val_loss: 0.2990
# Epoch 22/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4272 - val_loss: 0.2830
# Epoch 23/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4054 - val_loss: 0.2681
# Epoch 24/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3848 - val_loss: 0.2537
# Epoch 25/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3652 - val_loss: 0.2403
# Epoch 26/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3467 - val_loss: 0.2274
# Epoch 27/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3291 - val_loss: 0.2153
# Epoch 28/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3125 - val_loss: 0.2040
# Epoch 29/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2967 - val_loss: 0.1931
# Epoch 30/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2818 - val_loss: 0.1830
# Epoch 31/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2678 - val_loss: 0.1730
# Epoch 32/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2544 - val_loss: 0.1640
# Epoch 33/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2418 - val_loss: 0.1555
# Epoch 34/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2300 - val_loss: 0.1474
# Epoch 35/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2188 - val_loss: 0.1395
# Epoch 36/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2081 - val_loss: 0.1324
# Epoch 37/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1981 - val_loss: 0.1256
# Epoch 38/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1887 - val_loss: 0.1191
# Epoch 39/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1797 - val_loss: 0.1130
# Epoch 40/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1713 - val_loss: 0.1073
# Epoch 41/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1634 - val_loss: 0.1019
# Epoch 42/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1559 - val_loss: 0.0969
# Epoch 43/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1488 - val_loss: 0.0921
# Epoch 44/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1422 - val_loss: 0.0875
# Epoch 45/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1358 - val_loss: 0.0834
# Epoch 46/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1300 - val_loss: 0.0794
# Epoch 47/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1244 - val_loss: 0.0756
# Epoch 48/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1191 - val_loss: 0.0722
# Epoch 49/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1142 - val_loss: 0.0689
# Epoch 50/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1095 - val_loss: 0.0657
# Epoch 51/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1051 - val_loss: 0.0627
# Epoch 52/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1010 - val_loss: 0.0600
# Epoch 53/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0971 - val_loss: 0.0574
# Epoch 54/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0934 - val_loss: 0.0551
# Epoch 55/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0900 - val_loss: 0.0528
# Epoch 56/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0867 - val_loss: 0.0506
# Epoch 57/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0836 - val_loss: 0.0486
# Epoch 58/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0807 - val_loss: 0.0467
# Epoch 59/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0780 - val_loss: 0.0449
# Epoch 60/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0754 - val_loss: 0.0432
# Epoch 61/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0730 - val_loss: 0.0415
# Epoch 62/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0706 - val_loss: 0.0401
# Epoch 63/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0685 - val_loss: 0.0387
# Epoch 64/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0664 - val_loss: 0.0373
# Epoch 65/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0644 - val_loss: 0.0361
# Epoch 66/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0626 - val_loss: 0.0349
# Epoch 67/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0608 - val_loss: 0.0338
# Epoch 68/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0591 - val_loss: 0.0328
# Epoch 69/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0574 - val_loss: 0.0317
# Epoch 70/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0559 - val_loss: 0.0307
# Epoch 71/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0544 - val_loss: 0.0298
# Epoch 72/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0530 - val_loss: 0.0290
# Epoch 73/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0516 - val_loss: 0.0281
# Epoch 74/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0503 - val_loss: 0.0274
# Epoch 75/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0490 - val_loss: 0.0266
# Epoch 76/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0478 - val_loss: 0.0259
# Epoch 77/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0466 - val_loss: 0.0252
# Epoch 78/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0454 - val_loss: 0.0245
# Epoch 79/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0443 - val_loss: 0.0239
# Epoch 80/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0432 - val_loss: 0.0233
# Epoch 81/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0421 - val_loss: 0.0227
# Epoch 82/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0411 - val_loss: 0.0222
# Epoch 83/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0401 - val_loss: 0.0216
# Epoch 84/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0392 - val_loss: 0.0211
# Epoch 85/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0382 - val_loss: 0.0206
# Epoch 86/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0373 - val_loss: 0.0202
# Epoch 87/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0364 - val_loss: 0.0197
# Epoch 88/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0355 - val_loss: 0.0193
# Epoch 89/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0346 - val_loss: 0.0188
# Epoch 90/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0338 - val_loss: 0.0184
# Epoch 91/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0330 - val_loss: 0.0180
# Epoch 92/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0322 - val_loss: 0.0177
# Epoch 93/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0314 - val_loss: 0.0173
# Epoch 94/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0307 - val_loss: 0.0170
# Epoch 95/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0299 - val_loss: 0.0167
# Epoch 96/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0292 - val_loss: 0.0164
# Epoch 97/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0285 - val_loss: 0.0161
# Epoch 98/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0278 - val_loss: 0.0158
# Epoch 99/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0271 - val_loss: 0.0155
# Epoch 100/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0265 - val_loss: 0.0152
# Epoch 101/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0258 - val_loss: 0.0150
# Epoch 102/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0252 - val_loss: 0.0149
# Epoch 103/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0246 - val_loss: 0.0146
# Epoch 104/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0240 - val_loss: 0.0144
# Epoch 105/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0234 - val_loss: 0.0142
# Epoch 106/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0229 - val_loss: 0.0140
# Epoch 107/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0223 - val_loss: 0.0138
# Epoch 108/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0218 - val_loss: 0.0137
# Epoch 109/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0213 - val_loss: 0.0135
# Epoch 110/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0208 - val_loss: 0.0133
# Epoch 111/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0203 - val_loss: 0.0132
# Epoch 112/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0198 - val_loss: 0.0131
# Epoch 113/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0194 - val_loss: 0.0130
# Epoch 114/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0189 - val_loss: 0.0128
# Epoch 115/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0185 - val_loss: 0.0127
# Epoch 116/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0181 - val_loss: 0.0126
# Epoch 117/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0177 - val_loss: 0.0124
# Epoch 118/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0173 - val_loss: 0.0124
# Epoch 119/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0169 - val_loss: 0.0123
# Epoch 120/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0165 - val_loss: 0.0122
# Epoch 121/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0162 - val_loss: 0.0121
# Epoch 122/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0158 - val_loss: 0.0122
# Epoch 123/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0155 - val_loss: 0.0120
# Epoch 124/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0152 - val_loss: 0.0120
# Epoch 125/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0149 - val_loss: 0.0119
# Epoch 126/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0146 - val_loss: 0.0119
# Epoch 127/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0143 - val_loss: 0.0118
# Epoch 128/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0140 - val_loss: 0.0118
# Epoch 129/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0138 - val_loss: 0.0117
# Epoch 130/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0135 - val_loss: 0.0117
# Epoch 131/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0133 - val_loss: 0.0116
# Epoch 132/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0130 - val_loss: 0.0117
# Epoch 133/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0128 - val_loss: 0.0116
# Epoch 134/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0125 - val_loss: 0.0116
# Epoch 135/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0123 - val_loss: 0.0115
# Epoch 136/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0121 - val_loss: 0.0115
# Epoch 137/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0119 - val_loss: 0.0115
# Epoch 138/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0117 - val_loss: 0.0115
# Epoch 139/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0115 - val_loss: 0.0115
# Epoch 140/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0114 - val_loss: 0.0115
# Epoch 141/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0112 - val_loss: 0.0115
# Epoch 142/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 143/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0109 - val_loss: 0.0114
# Epoch 144/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0107 - val_loss: 0.0115
# Epoch 145/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0106 - val_loss: 0.0113
# Epoch 146/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0104 - val_loss: 0.0113
# Epoch 147/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0103 - val_loss: 0.0114
# Epoch 148/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0101 - val_loss: 0.0114
# Epoch 149/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0100 - val_loss: 0.0114
# Epoch 150/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0099 - val_loss: 0.0113
# Epoch 151/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0098 - val_loss: 0.0113
# Epoch 152/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0097 - val_loss: 0.0113
# Epoch 153/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0095 - val_loss: 0.0114
# Epoch 154/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0094 - val_loss: 0.0112
# Epoch 155/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0093 - val_loss: 0.0112
# Epoch 156/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0092 - val_loss: 0.0113
# Epoch 157/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0091 - val_loss: 0.0113
# Epoch 158/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0090 - val_loss: 0.0111
# Epoch 159/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0090 - val_loss: 0.0112
# Epoch 160/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0089 - val_loss: 0.0112
# Epoch 161/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0088 - val_loss: 0.0111
# Epoch 162/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0087 - val_loss: 0.0111
# Epoch 163/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0086 - val_loss: 0.0111
# Epoch 164/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0086 - val_loss: 0.0111
# Epoch 165/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0085 - val_loss: 0.0112
# Epoch 166/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0084 - val_loss: 0.0111
# Epoch 167/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0083 - val_loss: 0.0110
# Epoch 168/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0083 - val_loss: 0.0110
# Epoch 169/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0082 - val_loss: 0.0109
# Epoch 170/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0081 - val_loss: 0.0110
# Epoch 171/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0081 - val_loss: 0.0109
# Epoch 172/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0080 - val_loss: 0.0108
# Epoch 173/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0080 - val_loss: 0.0109
# Epoch 174/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0079 - val_loss: 0.0109
# Epoch 175/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0078 - val_loss: 0.0108
# Epoch 176/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0078 - val_loss: 0.0106
# Epoch 177/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0077 - val_loss: 0.0107
# Epoch 178/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0077 - val_loss: 0.0106
# Epoch 179/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0076 - val_loss: 0.0106
# Epoch 180/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0076 - val_loss: 0.0106
# Epoch 181/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0075 - val_loss: 0.0105
# Epoch 182/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0075 - val_loss: 0.0106
# Epoch 183/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0074 - val_loss: 0.0105
# Epoch 184/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0074 - val_loss: 0.0105
# Epoch 185/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0073 - val_loss: 0.0103
# Epoch 186/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0073 - val_loss: 0.0103
# Epoch 187/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0072 - val_loss: 0.0103
# Epoch 188/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0072 - val_loss: 0.0103
# Epoch 189/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.0103
# Epoch 190/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.0102
# Epoch 191/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0070 - val_loss: 0.0102
# Epoch 192/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0070 - val_loss: 0.0101
# Epoch 193/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0070 - val_loss: 0.0101
# Epoch 194/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0069 - val_loss: 0.0100
# Epoch 195/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0069 - val_loss: 0.0100
# Epoch 196/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0099
# Epoch 197/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0098
# Epoch 198/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.0098
# Epoch 199/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.0098
# Epoch 200/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.0097

# %%
df = pd.DataFrame(list(zip(RMSE_history_list, R2_history_list)),
                  columns=['RMSE', 'R2'])

df
# Out:
#        RMSE        R2
# 0  0.065170  0.950054
# 1  0.077083  0.895400
# 2  0.095141  0.882772

# %%
#model forecasting result
model.summary()
model=load_model("rbf-model.hdf5", custom_objects={'RBFLayer': RBFLayer}) #把儲存好的最佳模式讀入

batch_size=8
pred_train=(model.predict(data_in_norm,batch_size=batch_size))*(data_real_out_max-data_real_out_min)+data_real_out_min #針對訓練資料做預測
pred_test=(model.predict(test_in_norm,batch_size=batch_size))*(test_real_out_max-test_real_out_min)+test_real_out_min #針對測試資料做預測

rmse=[];r2=[];
rmse.append(np_RMSE(np.asarray(data_real_out),pred_train))
rmse.append(np_RMSE(np.asarray(test_real_out),pred_test))
r2.append(np_R2(np.asarray(data_real_out),pred_train))
r2.append(np_R2(np.asarray(test_real_out),pred_test))

rmse=np.asarray(rmse).reshape(1,2)
rmse=pd.DataFrame(rmse,columns=['train','test'])
r2=np.asarray(r2).reshape(1,2)
r2=pd.DataFrame(r2,columns=['train','test'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rbf_layer (RBFLayer)        (None, 5)                 30
#
#  activation (Activation)     (None, 5)                 0
#
#  dense (Dense)               (None, 1)                 6
#
# =================================================================
# Total params: 36
# Trainable params: 36
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Plot

# %%
import matplotlib.pyplot as plot

plot1 = plot.figure(1)
plot.scatter(test_real_out,pred_test)
plot.title("train R2=%s"%r2.iloc[0,0])
plot1 = plot.figure(2)
plot.plot(test_real_out)
plot.plot(pred_test)
plot.title("train RMSE=%s"%rmse.iloc[0,0])
plot1 = plot.figure(3)
plot.scatter(test_real_out,pred_test)
plot.title("test R2=%s"%r2.iloc[0,1])
plot1 = plot.figure(4)
plot.plot(test_real_out)
plot.plot(pred_test)
plot.title("test RMSE=%s"%rmse.iloc[0,1])
# Out:
# Text(0.5, 1.0, 'test RMSE=0.08470517')
