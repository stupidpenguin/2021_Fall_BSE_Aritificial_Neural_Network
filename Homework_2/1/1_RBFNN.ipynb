# %%
# -*- coding: utf-8 -*-

"""
Created on Thu Oct 17 18:33:06 2019

@author: steve
"""
# Out:
# '\nCreated on Thu Oct 17 18:33:06 2019\n\n@author: steve\n'

# %%
# rbf layer from https://github.com/PetraVidnerova/rbf_keras

from keras import backend as K
# from keras.engine.topology import Layer
from keras.layers import Layer
from keras.initializers import RandomUniform, Initializer, Constant
import numpy as np

# %%
class InitCentersRandom(Initializer):
    """ Initializer for initialization of centers of RBF network
        as random samples from the given data set.
    # Arguments
        X: matrix, dataset to choose the centers from (random rows
          are taken as centers)
    """

    def __init__(self, X):
        self.X = X

    def __call__(self, shape, dtype=None):
        assert shape[1] == self.X.shape[1]
        idx = np.random.randint(self.X.shape[0], size=shape[0])
        return self.X[idx, :]


class RBFLayer(Layer):
    """ Layer of Gaussian RBF units.
    # Example
    ```python
        model = Sequential()
        model.add(RBFLayer(10,
                           initializer=InitCentersRandom(X),
                           betas=1.0,
                           input_shape=(1,)))
        model.add(Dense(1))
    ```
    # Arguments
        output_dim: number of hidden units (i.e. number of outputs of the
                    layer)
        initializer: instance of initiliazer to initialize centers
        betas: float, initial value for betas
    """

    def __init__(self, output_dim, initializer=None, betas=1.0, **kwargs):
        self.output_dim = output_dim
        self.init_betas = betas
        if not initializer:
            self.initializer = RandomUniform(0.0, 1.0)
        else:
            self.initializer = initializer
        super(RBFLayer, self).__init__(**kwargs)

    def build(self, input_shape):

        self.centers = self.add_weight(name='centers',
                                       shape=(self.output_dim, input_shape[1]),
                                       initializer=self.initializer,
                                       trainable=True)
        self.betas = self.add_weight(name='betas',
                                     shape=(self.output_dim,),
                                     initializer=Constant(
                                         value=self.init_betas),
                                     # initializer='ones',
                                     trainable=True)

        super(RBFLayer, self).build(input_shape)

    def call(self, x):

        C = K.expand_dims(self.centers)
        H = K.transpose(C-K.transpose(x))
        return K.exp(-self.betas * K.sum(H**2, axis=1))

        # C = self.centers[np.newaxis, :, :]
        # X = x[:, np.newaxis, :]

        # diffnorm = K.sum((C-X)**2, axis=-1)
        # ret = K.exp( - self.betas * diffnorm)
        # return ret

    def compute_output_shape(self, input_shape):
        return (input_shape[0], self.output_dim)

    def get_config(self):
        # have to define get_config to be able to use model_from_json
        config = {
            'output_dim': self.output_dim
        }
        base_config = super(RBFLayer, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %% [markdown]
# ### read input & output data

# %%
import pandas as pd #與Panel、DataFrame 與 Series 相呼應

#read input & output data
x_train=open("../dataset/MackeyGlass/train_X.txt")
x_train=pd.read_csv(x_train, sep="\t",header=0)
y_train=open("../dataset/MackeyGlass/train_y.txt")
y_train=(pd.read_csv(y_train, sep="\t",header=0)).iloc[:,1]

x_test=open("../dataset/MackeyGlass/test_X.txt")
x_test=pd.read_csv(x_test, sep="\t",header=0)
y_test=open("../dataset/MackeyGlass/test_Y.txt")
y_test=(pd.read_csv(y_test, sep="\t",header=0)).iloc[:,1]

# %% [markdown]
# ### using input label

# %%
data_in=x_train
data_real_out=y_train
test_in=x_test
test_real_out=y_test

# %% [markdown]
# ### data normalization

# %%
data_in_max=data_in.max()
data_in_min=data_in.min()
data_in_norm=(data_in-data_in_min)/(data_in_max-data_in_min)
data_in_norm=np.asarray(data_in_norm)

data_real_out_max=data_real_out.max()
data_real_out_min=data_real_out.min()
data_real_out_norm=(data_real_out-data_real_out_min)/(data_real_out_max-data_real_out_min)
data_real_out_norm=np.asarray(data_real_out_norm)

test_in_max=test_in.max()
test_in_min=test_in.min()
test_in_norm=(test_in-test_in_min)/(test_in_max-test_in_min)
test_in_norm=np.asarray(test_in_norm)

test_real_out_max=test_real_out.max()
test_real_out_min=test_real_out.min()
test_real_out_norm=(test_real_out-test_real_out_min)/(test_real_out_max-test_real_out_min)
test_real_out_norm=np.asarray(test_real_out_norm)

# %% [markdown]
# ### Build Model

# %%
#define error function & calculate model's output error
def np_RMSE(output,output_pred):
    rmserror=0
    for i in range(len(output)):
        rmserror=rmserror+np.square(output[i]-output_pred[i])
    rmserror=np.sqrt(rmserror/len(output))
    return rmserror

def np_R2(output,output_pred):
    return np.square(np.corrcoef(output.reshape(np.size(output)),output_pred.reshape(np.size(output_pred)), False)[1,0])

# %% [markdown]
# #### 1-b. 以交叉驗證方式訓練BPNN模式，列初步同分組組合之RMSE與$R^2$值

# %%
from keras.models import Sequential,load_model
from keras import backend as K
from keras.layers import Dense
from keras.layers.core import Activation
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.optimizers import adam_v2
#from keras.layers.normalization import BatchNormalization
from sklearn.model_selection import KFold
from keras.callbacks import History
from keras.metrics import mean_squared_error as mserr

history = History()

RMSE_history_list = []
R2_history_list = []
seed = 7
best_RMSE = np.inf
kfold = KFold(n_splits=3, shuffle=False)
for train, validation in kfold.split(data_in_norm, data_real_out_norm):

    K.clear_session()
    # 模型結構
    model = Sequential()
    model.add(RBFLayer(10,initializer=InitCentersRandom(data_in_norm),betas=1.0,input_shape=(len(data_in_norm[0]),)))
    model.add(Activation('tanh'))
    model.add(Dense(1))

    # 模型相關設定
    learning_rate=1e-4 #設定學習速率
    adam = adam_v2.Adam(lr=learning_rate) #設定的優化器
    model.compile(optimizer=adam,loss="mse") #執行設定好的優化器和誤差函數
    # earlystopper = EarlyStopping(monitor='val_loss', patience=10, verbose=0) #設定early stopping的參數
    # checkpoint =ModelCheckpoint("rbf-model.hdf5",save_best_only=True)
    #每次迭代儲存模式，我設定了最終只儲存最佳的模式(當驗證誤差最小的時候)
    # callback_list=[earlystopper,checkpoint]
    model.fit(data_in_norm,data_real_out_norm,
              epochs=200, batch_size=8, validation_split=0.2, workers=8
              # callbacks=callback_list
              )

    prediction = np.squeeze(model.predict(data_in_norm[validation]))
    current_RMSE = np_RMSE(prediction, data_real_out_norm[validation])
    current_R2 = np_R2(prediction, data_real_out_norm[validation])
    RMSE_history_list.append(current_RMSE)
    R2_history_list.append(current_R2)

    if (current_RMSE < best_RMSE):
        best_RMSE = current_RMSE
        model.save("rbf-model.hdf5")
        print(f'best model updated!')
    #執行模式訓練并且把設定好的early stopping以及儲存模式參數套用到訓練中

#more details reference: https://keras.io/
# Out:
# Epoch 1/200
#  1/50 [..............................] - ETA: 7s - loss: 0.4962
# C:\Users\woody\AppData\Roaming\Python\Python38\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3925 - val_loss: 0.4630
# Epoch 2/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3435 - val_loss: 0.4147
# Epoch 3/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2996 - val_loss: 0.3708
# Epoch 4/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2607 - val_loss: 0.3316
# Epoch 5/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2266 - val_loss: 0.2960
# Epoch 6/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1965 - val_loss: 0.2645
# Epoch 7/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1706 - val_loss: 0.2363
# Epoch 8/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1482 - val_loss: 0.2119
# Epoch 9/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1291 - val_loss: 0.1904
# Epoch 10/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1129 - val_loss: 0.1713
# Epoch 11/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0992 - val_loss: 0.1549
# Epoch 12/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0877 - val_loss: 0.1405
# Epoch 13/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0781 - val_loss: 0.1281
# Epoch 14/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0701 - val_loss: 0.1170
# Epoch 15/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0635 - val_loss: 0.1080
# Epoch 16/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0580 - val_loss: 0.0998
# Epoch 17/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0534 - val_loss: 0.0927
# Epoch 18/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0495 - val_loss: 0.0868
# Epoch 19/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0462 - val_loss: 0.0814
# Epoch 20/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0433 - val_loss: 0.0768
# Epoch 21/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0409 - val_loss: 0.0726
# Epoch 22/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0387 - val_loss: 0.0688
# Epoch 23/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0368 - val_loss: 0.0656
# Epoch 24/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0350 - val_loss: 0.0626
# Epoch 25/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0335 - val_loss: 0.0599
# Epoch 26/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0320 - val_loss: 0.0574
# Epoch 27/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0306 - val_loss: 0.0554
# Epoch 28/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0293 - val_loss: 0.0532
# Epoch 29/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0281 - val_loss: 0.0514
# Epoch 30/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0269 - val_loss: 0.0496
# Epoch 31/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0258 - val_loss: 0.0478
# Epoch 32/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0248 - val_loss: 0.0464
# Epoch 33/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0238 - val_loss: 0.0450
# Epoch 34/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0228 - val_loss: 0.0434
# Epoch 35/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0219 - val_loss: 0.0422
# Epoch 36/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0211 - val_loss: 0.0412
# Epoch 37/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0203 - val_loss: 0.0398
# Epoch 38/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0195 - val_loss: 0.0386
# Epoch 39/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0188 - val_loss: 0.0375
# Epoch 40/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0181 - val_loss: 0.0364
# Epoch 41/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0175 - val_loss: 0.0353
# Epoch 42/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0168 - val_loss: 0.0344
# Epoch 43/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0163 - val_loss: 0.0337
# Epoch 44/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0157 - val_loss: 0.0326
# Epoch 45/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0152 - val_loss: 0.0318
# Epoch 46/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0148 - val_loss: 0.0310
# Epoch 47/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0143 - val_loss: 0.0303
# Epoch 48/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0139 - val_loss: 0.0296
# Epoch 49/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0135 - val_loss: 0.0289
# Epoch 50/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0131 - val_loss: 0.0282
# Epoch 51/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0128 - val_loss: 0.0274
# Epoch 52/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0125 - val_loss: 0.0268
# Epoch 53/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0122 - val_loss: 0.0263
# Epoch 54/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0119 - val_loss: 0.0258
# Epoch 55/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0116 - val_loss: 0.0252
# Epoch 56/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0114 - val_loss: 0.0246
# Epoch 57/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0111 - val_loss: 0.0242
# Epoch 58/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0109 - val_loss: 0.0237
# Epoch 59/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0107 - val_loss: 0.0232
# Epoch 60/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0106 - val_loss: 0.0228
# Epoch 61/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0104 - val_loss: 0.0223
# Epoch 62/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0102 - val_loss: 0.0222
# Epoch 63/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0101 - val_loss: 0.0217
# Epoch 64/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0099 - val_loss: 0.0213
# Epoch 65/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0098 - val_loss: 0.0210
# Epoch 66/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0097 - val_loss: 0.0208
# Epoch 67/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0096 - val_loss: 0.0203
# Epoch 68/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0094 - val_loss: 0.0202
# Epoch 69/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0093 - val_loss: 0.0198
# Epoch 70/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0092 - val_loss: 0.0195
# Epoch 71/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0091 - val_loss: 0.0194
# Epoch 72/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0090 - val_loss: 0.0190
# Epoch 73/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0090 - val_loss: 0.0189
# Epoch 74/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0089 - val_loss: 0.0186
# Epoch 75/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0088 - val_loss: 0.0184
# Epoch 76/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0087 - val_loss: 0.0184
# Epoch 77/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0086 - val_loss: 0.0180
# Epoch 78/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0086 - val_loss: 0.0179
# Epoch 79/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0085 - val_loss: 0.0177
# Epoch 80/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0084 - val_loss: 0.0176
# Epoch 81/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0084 - val_loss: 0.0173
# Epoch 82/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0083 - val_loss: 0.0172
# Epoch 83/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0082 - val_loss: 0.0170
# Epoch 84/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0081 - val_loss: 0.0170
# Epoch 85/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0081 - val_loss: 0.0168
# Epoch 86/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0080 - val_loss: 0.0169
# Epoch 87/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0079 - val_loss: 0.0167
# Epoch 88/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0079 - val_loss: 0.0166
# Epoch 89/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0078 - val_loss: 0.0164
# Epoch 90/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0077 - val_loss: 0.0165
# Epoch 91/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0077 - val_loss: 0.0162
# Epoch 92/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0076 - val_loss: 0.0162
# Epoch 93/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0076 - val_loss: 0.0160
# Epoch 94/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0075 - val_loss: 0.0162
# Epoch 95/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0074 - val_loss: 0.0158
# Epoch 96/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0074 - val_loss: 0.0160
# Epoch 97/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0073 - val_loss: 0.0158
# Epoch 98/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0072 - val_loss: 0.0158
# Epoch 99/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0072 - val_loss: 0.0156
# Epoch 100/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.0158
# Epoch 101/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.0155
# Epoch 102/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0070 - val_loss: 0.0155
# Epoch 103/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0069 - val_loss: 0.0154
# Epoch 104/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0069 - val_loss: 0.0155
# Epoch 105/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0152
# Epoch 106/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0154
# Epoch 107/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.0153
# Epoch 108/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.0155
# Epoch 109/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.0151
# Epoch 110/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.0153
# Epoch 111/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.0152
# Epoch 112/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0152
# Epoch 113/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0151
# Epoch 114/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0151
# Epoch 115/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0150
# Epoch 116/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0152
# Epoch 117/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.0150
# Epoch 118/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.0150
# Epoch 119/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0150
# Epoch 120/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0148
# Epoch 121/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0149
# Epoch 122/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0150
# Epoch 123/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0151
# Epoch 124/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0148
# Epoch 125/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.0149
# Epoch 126/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.0147
# Epoch 127/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0148
# Epoch 128/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0151
# Epoch 129/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0147
# Epoch 130/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0146
# Epoch 131/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.0147
# Epoch 132/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.0147
# Epoch 133/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.0147
# Epoch 134/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0147
# Epoch 135/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0147
# Epoch 136/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0149
# Epoch 137/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0145
# Epoch 138/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0147
# Epoch 139/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0146
# Epoch 140/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0147
# Epoch 141/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 0.0145
# Epoch 142/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 0.0148
# Epoch 143/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0146
# Epoch 144/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0147
# Epoch 145/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0146
# Epoch 146/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0146
# Epoch 147/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0143
# Epoch 148/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0143
# Epoch 149/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0146
# Epoch 150/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0144
# Epoch 151/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0144
# Epoch 152/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0147
# Epoch 153/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0145
# Epoch 154/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0145
# Epoch 155/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0045 - val_loss: 0.0143
# Epoch 156/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0045 - val_loss: 0.0142
# Epoch 157/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0045 - val_loss: 0.0143
# Epoch 158/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0144
# Epoch 159/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0144
# Epoch 160/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0141
# Epoch 161/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0144
# Epoch 162/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0144
# Epoch 163/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0141
# Epoch 164/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0042 - val_loss: 0.0143
# Epoch 165/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0042 - val_loss: 0.0142
# Epoch 166/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0042 - val_loss: 0.0141
# Epoch 167/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0042 - val_loss: 0.0144
# Epoch 168/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0041 - val_loss: 0.0143
# Epoch 169/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0041 - val_loss: 0.0142
# Epoch 170/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0041 - val_loss: 0.0143
# Epoch 171/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0040 - val_loss: 0.0141
# Epoch 172/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0040 - val_loss: 0.0141
# Epoch 173/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0040 - val_loss: 0.0138
# Epoch 174/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0040 - val_loss: 0.0139
# Epoch 175/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0142
# Epoch 176/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0142
# Epoch 177/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0141
# Epoch 178/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0140
# Epoch 179/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0038 - val_loss: 0.0140
# Epoch 180/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0038 - val_loss: 0.0142
# Epoch 181/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0038 - val_loss: 0.0141
# Epoch 182/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0038 - val_loss: 0.0137
# Epoch 183/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0038 - val_loss: 0.0138
# Epoch 184/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0137
# Epoch 185/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0135
# Epoch 186/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0138
# Epoch 187/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0136
# Epoch 188/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0137
# Epoch 189/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0036 - val_loss: 0.0138
# Epoch 190/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0036 - val_loss: 0.0139
# Epoch 191/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0036 - val_loss: 0.0133
# Epoch 192/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0036 - val_loss: 0.0136
# Epoch 193/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0036 - val_loss: 0.0135
# Epoch 194/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0035 - val_loss: 0.0134
# Epoch 195/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0035 - val_loss: 0.0134
# Epoch 196/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0035 - val_loss: 0.0138
# Epoch 197/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0035 - val_loss: 0.0136
# Epoch 198/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0035 - val_loss: 0.0138
# Epoch 199/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0034 - val_loss: 0.0133
# Epoch 200/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0034 - val_loss: 0.0137
# best model updated!
# Epoch 1/200
# 50/50 [==============================] - 0s 3ms/step - loss: 2.7749 - val_loss: 2.2884
# Epoch 2/200
# 50/50 [==============================] - 0s 2ms/step - loss: 2.6326 - val_loss: 2.1733
# Epoch 3/200
# 50/50 [==============================] - 0s 2ms/step - loss: 2.4966 - val_loss: 2.0614
# Epoch 4/200
# 50/50 [==============================] - 0s 2ms/step - loss: 2.3664 - val_loss: 1.9558
# Epoch 5/200
# 50/50 [==============================] - 0s 2ms/step - loss: 2.2427 - val_loss: 1.8545
# Epoch 6/200
# 50/50 [==============================] - 0s 2ms/step - loss: 2.1245 - val_loss: 1.7605
# Epoch 7/200
# 50/50 [==============================] - 0s 2ms/step - loss: 2.0128 - val_loss: 1.6686
# Epoch 8/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.9063 - val_loss: 1.5818
# Epoch 9/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.8054 - val_loss: 1.5004
# Epoch 10/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.7095 - val_loss: 1.4233
# Epoch 11/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.6187 - val_loss: 1.3492
# Epoch 12/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.5322 - val_loss: 1.2804
# Epoch 13/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.4504 - val_loss: 1.2145
# Epoch 14/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.3732 - val_loss: 1.1516
# Epoch 15/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.2995 - val_loss: 1.0931
# Epoch 16/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.2304 - val_loss: 1.0364
# Epoch 17/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.1645 - val_loss: 0.9837
# Epoch 18/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.1028 - val_loss: 0.9334
# Epoch 19/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.0441 - val_loss: 0.8865
# Epoch 20/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.9889 - val_loss: 0.8421
# Epoch 21/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.9372 - val_loss: 0.7993
# Epoch 22/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.8879 - val_loss: 0.7599
# Epoch 23/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.8418 - val_loss: 0.7228
# Epoch 24/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7984 - val_loss: 0.6878
# Epoch 25/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7575 - val_loss: 0.6547
# Epoch 26/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7193 - val_loss: 0.6230
# Epoch 27/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6831 - val_loss: 0.5940
# Epoch 28/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6493 - val_loss: 0.5668
# Epoch 29/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6177 - val_loss: 0.5402
# Epoch 30/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5879 - val_loss: 0.5159
# Epoch 31/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5599 - val_loss: 0.4936
# Epoch 32/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5340 - val_loss: 0.4720
# Epoch 33/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5094 - val_loss: 0.4520
# Epoch 34/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4867 - val_loss: 0.4330
# Epoch 35/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4653 - val_loss: 0.4150
# Epoch 36/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4452 - val_loss: 0.3991
# Epoch 37/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4267 - val_loss: 0.3833
# Epoch 38/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4091 - val_loss: 0.3689
# Epoch 39/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3928 - val_loss: 0.3557
# Epoch 40/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3777 - val_loss: 0.3428
# Epoch 41/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3635 - val_loss: 0.3304
# Epoch 42/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3502 - val_loss: 0.3194
# Epoch 43/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3378 - val_loss: 0.3088
# Epoch 44/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3262 - val_loss: 0.2990
# Epoch 45/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3154 - val_loss: 0.2898
# Epoch 46/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3052 - val_loss: 0.2814
# Epoch 47/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2959 - val_loss: 0.2728
# Epoch 48/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2869 - val_loss: 0.2651
# Epoch 49/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2784 - val_loss: 0.2584
# Epoch 50/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2707 - val_loss: 0.2514
# Epoch 51/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2633 - val_loss: 0.2449
# Epoch 52/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2563 - val_loss: 0.2388
# Epoch 53/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2497 - val_loss: 0.2331
# Epoch 54/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2434 - val_loss: 0.2279
# Epoch 55/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2376 - val_loss: 0.2224
# Epoch 56/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2319 - val_loss: 0.2174
# Epoch 57/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2265 - val_loss: 0.2127
# Epoch 58/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2213 - val_loss: 0.2082
# Epoch 59/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2164 - val_loss: 0.2037
# Epoch 60/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2117 - val_loss: 0.1994
# Epoch 61/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2071 - val_loss: 0.1954
# Epoch 62/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2027 - val_loss: 0.1916
# Epoch 63/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1985 - val_loss: 0.1877
# Epoch 64/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1943 - val_loss: 0.1840
# Epoch 65/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1903 - val_loss: 0.1805
# Epoch 66/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1864 - val_loss: 0.1769
# Epoch 67/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1826 - val_loss: 0.1735
# Epoch 68/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1788 - val_loss: 0.1702
# Epoch 69/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1752 - val_loss: 0.1668
# Epoch 70/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1716 - val_loss: 0.1636
# Epoch 71/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1681 - val_loss: 0.1605
# Epoch 72/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1646 - val_loss: 0.1573
# Epoch 73/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1612 - val_loss: 0.1544
# Epoch 74/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1579 - val_loss: 0.1513
# Epoch 75/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1546 - val_loss: 0.1484
# Epoch 76/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1514 - val_loss: 0.1454
# Epoch 77/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1481 - val_loss: 0.1426
# Epoch 78/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1450 - val_loss: 0.1398
# Epoch 79/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1418 - val_loss: 0.1370
# Epoch 80/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1388 - val_loss: 0.1342
# Epoch 81/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1357 - val_loss: 0.1315
# Epoch 82/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1327 - val_loss: 0.1289
# Epoch 83/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1298 - val_loss: 0.1262
# Epoch 84/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1268 - val_loss: 0.1235
# Epoch 85/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1240 - val_loss: 0.1210
# Epoch 86/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1211 - val_loss: 0.1183
# Epoch 87/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1182 - val_loss: 0.1159
# Epoch 88/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1155 - val_loss: 0.1134
# Epoch 89/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1127 - val_loss: 0.1109
# Epoch 90/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1100 - val_loss: 0.1085
# Epoch 91/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1073 - val_loss: 0.1060
# Epoch 92/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1046 - val_loss: 0.1036
# Epoch 93/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1020 - val_loss: 0.1012
# Epoch 94/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0994 - val_loss: 0.0989
# Epoch 95/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0969 - val_loss: 0.0966
# Epoch 96/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0944 - val_loss: 0.0943
# Epoch 97/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0919 - val_loss: 0.0921
# Epoch 98/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0894 - val_loss: 0.0899
# Epoch 99/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0870 - val_loss: 0.0877
# Epoch 100/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0846 - val_loss: 0.0855
# Epoch 101/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0823 - val_loss: 0.0834
# Epoch 102/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0800 - val_loss: 0.0813
# Epoch 103/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0777 - val_loss: 0.0792
# Epoch 104/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0755 - val_loss: 0.0771
# Epoch 105/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0733 - val_loss: 0.0752
# Epoch 106/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0711 - val_loss: 0.0731
# Epoch 107/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0690 - val_loss: 0.0712
# Epoch 108/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0669 - val_loss: 0.0693
# Epoch 109/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0649 - val_loss: 0.0674
# Epoch 110/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0628 - val_loss: 0.0655
# Epoch 111/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0609 - val_loss: 0.0638
# Epoch 112/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0590 - val_loss: 0.0620
# Epoch 113/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0571 - val_loss: 0.0602
# Epoch 114/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0553 - val_loss: 0.0585
# Epoch 115/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0534 - val_loss: 0.0568
# Epoch 116/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0517 - val_loss: 0.0551
# Epoch 117/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0500 - val_loss: 0.0535
# Epoch 118/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0483 - val_loss: 0.0520
# Epoch 119/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0467 - val_loss: 0.0504
# Epoch 120/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0451 - val_loss: 0.0489
# Epoch 121/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0436 - val_loss: 0.0474
# Epoch 122/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0420 - val_loss: 0.0460
# Epoch 123/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0406 - val_loss: 0.0446
# Epoch 124/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0392 - val_loss: 0.0433
# Epoch 125/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0378 - val_loss: 0.0419
# Epoch 126/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0365 - val_loss: 0.0407
# Epoch 127/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0352 - val_loss: 0.0394
# Epoch 128/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0339 - val_loss: 0.0382
# Epoch 129/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0327 - val_loss: 0.0370
# Epoch 130/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0316 - val_loss: 0.0359
# Epoch 131/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0305 - val_loss: 0.0348
# Epoch 132/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0294 - val_loss: 0.0337
# Epoch 133/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0283 - val_loss: 0.0326
# Epoch 134/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0273 - val_loss: 0.0316
# Epoch 135/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0264 - val_loss: 0.0307
# Epoch 136/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0254 - val_loss: 0.0297
# Epoch 137/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0245 - val_loss: 0.0288
# Epoch 138/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0237 - val_loss: 0.0280
# Epoch 139/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0229 - val_loss: 0.0271
# Epoch 140/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0221 - val_loss: 0.0263
# Epoch 141/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0213 - val_loss: 0.0256
# Epoch 142/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0206 - val_loss: 0.0248
# Epoch 143/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0199 - val_loss: 0.0241
# Epoch 144/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0193 - val_loss: 0.0234
# Epoch 145/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0186 - val_loss: 0.0228
# Epoch 146/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0181 - val_loss: 0.0222
# Epoch 147/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0175 - val_loss: 0.0216
# Epoch 148/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0170 - val_loss: 0.0209
# Epoch 149/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0165 - val_loss: 0.0204
# Epoch 150/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0160 - val_loss: 0.0199
# Epoch 151/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0155 - val_loss: 0.0194
# Epoch 152/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0151 - val_loss: 0.0189
# Epoch 153/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0147 - val_loss: 0.0184
# Epoch 154/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0143 - val_loss: 0.0181
# Epoch 155/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0139 - val_loss: 0.0176
# Epoch 156/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0136 - val_loss: 0.0173
# Epoch 157/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0133 - val_loss: 0.0169
# Epoch 158/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0130 - val_loss: 0.0166
# Epoch 159/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0127 - val_loss: 0.0163
# Epoch 160/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0124 - val_loss: 0.0160
# Epoch 161/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0122 - val_loss: 0.0157
# Epoch 162/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0119 - val_loss: 0.0154
# Epoch 163/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0117 - val_loss: 0.0152
# Epoch 164/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0115 - val_loss: 0.0149
# Epoch 165/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0113 - val_loss: 0.0147
# Epoch 166/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0111 - val_loss: 0.0145
# Epoch 167/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0109 - val_loss: 0.0143
# Epoch 168/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0108 - val_loss: 0.0141
# Epoch 169/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0106 - val_loss: 0.0140
# Epoch 170/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0105 - val_loss: 0.0139
# Epoch 171/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0103 - val_loss: 0.0137
# Epoch 172/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0102 - val_loss: 0.0135
# Epoch 173/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0101 - val_loss: 0.0135
# Epoch 174/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0100 - val_loss: 0.0133
# Epoch 175/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0098 - val_loss: 0.0132
# Epoch 176/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0098 - val_loss: 0.0131
# Epoch 177/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0096 - val_loss: 0.0131
# Epoch 178/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0095 - val_loss: 0.0129
# Epoch 179/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0094 - val_loss: 0.0129
# Epoch 180/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0093 - val_loss: 0.0128
# Epoch 181/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0093 - val_loss: 0.0127
# Epoch 182/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0092 - val_loss: 0.0126
# Epoch 183/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0091 - val_loss: 0.0126
# Epoch 184/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0090 - val_loss: 0.0125
# Epoch 185/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0090 - val_loss: 0.0127
# Epoch 186/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0089 - val_loss: 0.0124
# Epoch 187/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0088 - val_loss: 0.0124
# Epoch 188/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0087 - val_loss: 0.0124
# Epoch 189/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0087 - val_loss: 0.0123
# Epoch 190/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0086 - val_loss: 0.0122
# Epoch 191/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0085 - val_loss: 0.0123
# Epoch 192/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0084 - val_loss: 0.0122
# Epoch 193/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0084 - val_loss: 0.0122
# Epoch 194/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0083 - val_loss: 0.0123
# Epoch 195/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0082 - val_loss: 0.0122
# Epoch 196/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0082 - val_loss: 0.0120
# Epoch 197/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0081 - val_loss: 0.0121
# Epoch 198/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0081 - val_loss: 0.0121
# Epoch 199/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0080 - val_loss: 0.0120
# Epoch 200/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0079 - val_loss: 0.0121
# Epoch 1/200
# 50/50 [==============================] - 0s 3ms/step - loss: 1.5145 - val_loss: 1.4751
# Epoch 2/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.4119 - val_loss: 1.3794
# Epoch 3/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.3150 - val_loss: 1.2887
# Epoch 4/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.2240 - val_loss: 1.2020
# Epoch 5/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.1373 - val_loss: 1.1216
# Epoch 6/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.0561 - val_loss: 1.0449
# Epoch 7/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.9794 - val_loss: 0.9729
# Epoch 8/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.9074 - val_loss: 0.9042
# Epoch 9/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.8396 - val_loss: 0.8400
# Epoch 10/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7760 - val_loss: 0.7800
# Epoch 11/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7164 - val_loss: 0.7237
# Epoch 12/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6608 - val_loss: 0.6704
# Epoch 13/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6085 - val_loss: 0.6209
# Epoch 14/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5599 - val_loss: 0.5741
# Epoch 15/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5144 - val_loss: 0.5310
# Epoch 16/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4722 - val_loss: 0.4903
# Epoch 17/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4329 - val_loss: 0.4522
# Epoch 18/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3962 - val_loss: 0.4174
# Epoch 19/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3623 - val_loss: 0.3849
# Epoch 20/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3310 - val_loss: 0.3541
# Epoch 21/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3019 - val_loss: 0.3259
# Epoch 22/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2750 - val_loss: 0.2999
# Epoch 23/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2503 - val_loss: 0.2755
# Epoch 24/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2275 - val_loss: 0.2532
# Epoch 25/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2066 - val_loss: 0.2326
# Epoch 26/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1874 - val_loss: 0.2134
# Epoch 27/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1698 - val_loss: 0.1960
# Epoch 28/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1538 - val_loss: 0.1797
# Epoch 29/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1392 - val_loss: 0.1649
# Epoch 30/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1258 - val_loss: 0.1516
# Epoch 31/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1138 - val_loss: 0.1392
# Epoch 32/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1029 - val_loss: 0.1280
# Epoch 33/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0930 - val_loss: 0.1178
# Epoch 34/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0840 - val_loss: 0.1085
# Epoch 35/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0760 - val_loss: 0.1001
# Epoch 36/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0689 - val_loss: 0.0923
# Epoch 37/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0625 - val_loss: 0.0853
# Epoch 38/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0567 - val_loss: 0.0791
# Epoch 39/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0516 - val_loss: 0.0734
# Epoch 40/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0471 - val_loss: 0.0684
# Epoch 41/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0431 - val_loss: 0.0640
# Epoch 42/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0396 - val_loss: 0.0597
# Epoch 43/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0364 - val_loss: 0.0561
# Epoch 44/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0337 - val_loss: 0.0527
# Epoch 45/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0313 - val_loss: 0.0498
# Epoch 46/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0292 - val_loss: 0.0471
# Epoch 47/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0274 - val_loss: 0.0448
# Epoch 48/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0258 - val_loss: 0.0426
# Epoch 49/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0244 - val_loss: 0.0407
# Epoch 50/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0232 - val_loss: 0.0389
# Epoch 51/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0221 - val_loss: 0.0374
# Epoch 52/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0211 - val_loss: 0.0360
# Epoch 53/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0203 - val_loss: 0.0347
# Epoch 54/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0196 - val_loss: 0.0335
# Epoch 55/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0189 - val_loss: 0.0325
# Epoch 56/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0184 - val_loss: 0.0315
# Epoch 57/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0178 - val_loss: 0.0306
# Epoch 58/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0174 - val_loss: 0.0297
# Epoch 59/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0170 - val_loss: 0.0289
# Epoch 60/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0166 - val_loss: 0.0282
# Epoch 61/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0162 - val_loss: 0.0275
# Epoch 62/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0159 - val_loss: 0.0270
# Epoch 63/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0156 - val_loss: 0.0264
# Epoch 64/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0153 - val_loss: 0.0258
# Epoch 65/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0150 - val_loss: 0.0253
# Epoch 66/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0148 - val_loss: 0.0247
# Epoch 67/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0145 - val_loss: 0.0243
# Epoch 68/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0143 - val_loss: 0.0238
# Epoch 69/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0140 - val_loss: 0.0234
# Epoch 70/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0138 - val_loss: 0.0230
# Epoch 71/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0136 - val_loss: 0.0225
# Epoch 72/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0134 - val_loss: 0.0222
# Epoch 73/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0132 - val_loss: 0.0218
# Epoch 74/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0130 - val_loss: 0.0214
# Epoch 75/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0128 - val_loss: 0.0211
# Epoch 76/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0126 - val_loss: 0.0207
# Epoch 77/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0124 - val_loss: 0.0204
# Epoch 78/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0123 - val_loss: 0.0201
# Epoch 79/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0121 - val_loss: 0.0198
# Epoch 80/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0120 - val_loss: 0.0195
# Epoch 81/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0118 - val_loss: 0.0192
# Epoch 82/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0117 - val_loss: 0.0189
# Epoch 83/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0115 - val_loss: 0.0186
# Epoch 84/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0114 - val_loss: 0.0184
# Epoch 85/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0113 - val_loss: 0.0181
# Epoch 86/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0111 - val_loss: 0.0179
# Epoch 87/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0110 - val_loss: 0.0177
# Epoch 88/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0109 - val_loss: 0.0174
# Epoch 89/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0108 - val_loss: 0.0172
# Epoch 90/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0107 - val_loss: 0.0169
# Epoch 91/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0106 - val_loss: 0.0168
# Epoch 92/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0105 - val_loss: 0.0166
# Epoch 93/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0104 - val_loss: 0.0164
# Epoch 94/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0103 - val_loss: 0.0162
# Epoch 95/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0102 - val_loss: 0.0160
# Epoch 96/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0101 - val_loss: 0.0158
# Epoch 97/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0100 - val_loss: 0.0157
# Epoch 98/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0099 - val_loss: 0.0155
# Epoch 99/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0098 - val_loss: 0.0153
# Epoch 100/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0098 - val_loss: 0.0152
# Epoch 101/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0097 - val_loss: 0.0150
# Epoch 102/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0096 - val_loss: 0.0149
# Epoch 103/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0095 - val_loss: 0.0147
# Epoch 104/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0095 - val_loss: 0.0146
# Epoch 105/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0094 - val_loss: 0.0144
# Epoch 106/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0093 - val_loss: 0.0143
# Epoch 107/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0093 - val_loss: 0.0142
# Epoch 108/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0092 - val_loss: 0.0140
# Epoch 109/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0092 - val_loss: 0.0140
# Epoch 110/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0091 - val_loss: 0.0139
# Epoch 111/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0090 - val_loss: 0.0137
# Epoch 112/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0090 - val_loss: 0.0137
# Epoch 113/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0089 - val_loss: 0.0135
# Epoch 114/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0089 - val_loss: 0.0135
# Epoch 115/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0088 - val_loss: 0.0134
# Epoch 116/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0087 - val_loss: 0.0133
# Epoch 117/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0087 - val_loss: 0.0132
# Epoch 118/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0087 - val_loss: 0.0131
# Epoch 119/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0086 - val_loss: 0.0131
# Epoch 120/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0085 - val_loss: 0.0130
# Epoch 121/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0085 - val_loss: 0.0129
# Epoch 122/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0084 - val_loss: 0.0128
# Epoch 123/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0084 - val_loss: 0.0127
# Epoch 124/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0083 - val_loss: 0.0126
# Epoch 125/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0083 - val_loss: 0.0126
# Epoch 126/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0082 - val_loss: 0.0125
# Epoch 127/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0082 - val_loss: 0.0125
# Epoch 128/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0081 - val_loss: 0.0124
# Epoch 129/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0080 - val_loss: 0.0124
# Epoch 130/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0080 - val_loss: 0.0123
# Epoch 131/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0079 - val_loss: 0.0123
# Epoch 132/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0079 - val_loss: 0.0121
# Epoch 133/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0078 - val_loss: 0.0121
# Epoch 134/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0078 - val_loss: 0.0121
# Epoch 135/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0077 - val_loss: 0.0120
# Epoch 136/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0077 - val_loss: 0.0119
# Epoch 137/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0076 - val_loss: 0.0119
# Epoch 138/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0076 - val_loss: 0.0118
# Epoch 139/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0075 - val_loss: 0.0118
# Epoch 140/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0075 - val_loss: 0.0117
# Epoch 141/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0074 - val_loss: 0.0117
# Epoch 142/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0074 - val_loss: 0.0116
# Epoch 143/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0073 - val_loss: 0.0116
# Epoch 144/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0073 - val_loss: 0.0115
# Epoch 145/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0072 - val_loss: 0.0115
# Epoch 146/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0072 - val_loss: 0.0115
# Epoch 147/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.0115
# Epoch 148/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.0114
# Epoch 149/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0070 - val_loss: 0.0113
# Epoch 150/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0070 - val_loss: 0.0112
# Epoch 151/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0069 - val_loss: 0.0111
# Epoch 152/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0069 - val_loss: 0.0113
# Epoch 153/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0111
# Epoch 154/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0112
# Epoch 155/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.0111
# Epoch 156/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.0109
# Epoch 157/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.0109
# Epoch 158/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.0109
# Epoch 159/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.0109
# Epoch 160/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.0107
# Epoch 161/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0107
# Epoch 162/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0107
# Epoch 163/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0106
# Epoch 164/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0105
# Epoch 165/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0105
# Epoch 166/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0106
# Epoch 167/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0105
# Epoch 168/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.0105
# Epoch 169/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.0104
# Epoch 170/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0103
# Epoch 171/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0104
# Epoch 172/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0103
# Epoch 173/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0102
# Epoch 174/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0102
# Epoch 175/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0101
# Epoch 176/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0101
# Epoch 177/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.0101
# Epoch 178/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.0099
# Epoch 179/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0099
# Epoch 180/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0098
# Epoch 181/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0099
# Epoch 182/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0098
# Epoch 183/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0097
# Epoch 184/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.0098
# Epoch 185/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.0097
# Epoch 186/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.0097
# Epoch 187/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0096
# Epoch 188/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0094
# Epoch 189/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0095
# Epoch 190/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0096
# Epoch 191/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0093
# Epoch 192/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0095
# Epoch 193/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0094
# Epoch 194/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0093
# Epoch 195/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 0.0094
# Epoch 196/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 0.0093
# Epoch 197/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 0.0092
# Epoch 198/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0092
# Epoch 199/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0091
# Epoch 200/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0092

# %%
df = pd.DataFrame(list(zip(RMSE_history_list, R2_history_list)),
                  columns=['RMSE', 'R2'])

df
# Out:
#        RMSE        R2
# 0  0.052599  0.963740
# 1  0.091319  0.854388
# 2  0.088134  0.904459

# %%
#model forecasting result
model.summary()
model=load_model("rbf-model.hdf5", custom_objects={'RBFLayer': RBFLayer}) #把儲存好的最佳模式讀入

batch_size=8
pred_train=(model.predict(data_in_norm,batch_size=batch_size))*(data_real_out_max-data_real_out_min)+data_real_out_min #針對訓練資料做預測
pred_test=(model.predict(test_in_norm,batch_size=batch_size))*(test_real_out_max-test_real_out_min)+test_real_out_min #針對測試資料做預測

rmse=[];r2=[];
rmse.append(np_RMSE(np.asarray(data_real_out),pred_train))
rmse.append(np_RMSE(np.asarray(test_real_out),pred_test))
r2.append(np_R2(np.asarray(data_real_out),pred_train))
r2.append(np_R2(np.asarray(test_real_out),pred_test))

rmse=np.asarray(rmse).reshape(1,2)
rmse=pd.DataFrame(rmse,columns=['train','test'])
r2=np.asarray(r2).reshape(1,2)
r2=pd.DataFrame(r2,columns=['train','test'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rbf_layer (RBFLayer)        (None, 10)                60
#
#  activation (Activation)     (None, 10)                0
#
#  dense (Dense)               (None, 1)                 11
#
# =================================================================
# Total params: 71
# Trainable params: 71
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Plot

# %%
import matplotlib.pyplot as plot

plot1 = plot.figure(1)
plot.scatter(test_real_out,pred_test)
plot.title("train R2=%s"%r2.iloc[0,0])
plot1 = plot.figure(2)
plot.plot(test_real_out)
plot.plot(pred_test)
plot.title("train RMSE=%s"%rmse.iloc[0,0])
plot1 = plot.figure(3)
plot.scatter(test_real_out,pred_test)
plot.title("test R2=%s"%r2.iloc[0,1])
plot1 = plot.figure(4)
plot.plot(test_real_out)
plot.plot(pred_test)
plot.title("test RMSE=%s"%rmse.iloc[0,1])
# Out:
# Text(0.5, 1.0, 'test RMSE=0.080668315')
