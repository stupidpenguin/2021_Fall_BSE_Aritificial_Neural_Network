# %%
# -*- coding: utf-8 -*-

"""
Created on Thu Oct 17 18:33:06 2019

@author: steve
"""
# Out:
# '\nCreated on Thu Oct 17 18:33:06 2019\n\n@author: steve\n'

# %%
# rbf layer from https://github.com/PetraVidnerova/rbf_keras

from keras import backend as K
# from keras.engine.topology import Layer
from keras.layers import Layer
from keras.initializers import RandomUniform, Initializer, Constant
import numpy as np

# %%
class InitCentersRandom(Initializer):
    """ Initializer for initialization of centers of RBF network
        as random samples from the given data set.
    # Arguments
        X: matrix, dataset to choose the centers from (random rows
          are taken as centers)
    """

    def __init__(self, X):
        self.X = X

    def __call__(self, shape, dtype=None):
        assert shape[1] == self.X.shape[1]
        idx = np.random.randint(self.X.shape[0], size=shape[0])
        return self.X[idx, :]


class RBFLayer(Layer):
    """ Layer of Gaussian RBF units.
    # Example
    ```python
        model = Sequential()
        model.add(RBFLayer(10,
                           initializer=InitCentersRandom(X),
                           betas=1.0,
                           input_shape=(1,)))
        model.add(Dense(1))
    ```
    # Arguments
        output_dim: number of hidden units (i.e. number of outputs of the
                    layer)
        initializer: instance of initiliazer to initialize centers
        betas: float, initial value for betas
    """

    def __init__(self, output_dim, initializer=None, betas=1.0, **kwargs):
        self.output_dim = output_dim
        self.init_betas = betas
        if not initializer:
            self.initializer = RandomUniform(0.0, 1.0)
        else:
            self.initializer = initializer
        super(RBFLayer, self).__init__(**kwargs)

    def build(self, input_shape):

        self.centers = self.add_weight(name='centers',
                                       shape=(self.output_dim, input_shape[1]),
                                       initializer=self.initializer,
                                       trainable=True)
        self.betas = self.add_weight(name='betas',
                                     shape=(self.output_dim,),
                                     initializer=Constant(
                                         value=self.init_betas),
                                     # initializer='ones',
                                     trainable=True)

        super(RBFLayer, self).build(input_shape)

    def call(self, x):

        C = K.expand_dims(self.centers)
        H = K.transpose(C-K.transpose(x))
        return K.exp(-self.betas * K.sum(H**2, axis=1))

        # C = self.centers[np.newaxis, :, :]
        # X = x[:, np.newaxis, :]

        # diffnorm = K.sum((C-X)**2, axis=-1)
        # ret = K.exp( - self.betas * diffnorm)
        # return ret

    def compute_output_shape(self, input_shape):
        return (input_shape[0], self.output_dim)

    def get_config(self):
        # have to define get_config to be able to use model_from_json
        config = {
            'output_dim': self.output_dim
        }
        base_config = super(RBFLayer, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %% [markdown]
# ### read input & output data

# %%
import pandas as pd #與Panel、DataFrame 與 Series 相呼應

#read input & output data
x_train=open("../dataset/MackeyGlass/train_X.txt")
x_train=pd.read_csv(x_train, sep="\t",header=0)
y_train=open("../dataset/MackeyGlass/train_y.txt")
y_train=(pd.read_csv(y_train, sep="\t",header=0)).iloc[:,1]

x_test=open("../dataset/MackeyGlass/test_X.txt")
x_test=pd.read_csv(x_test, sep="\t",header=0)
y_test=open("../dataset/MackeyGlass/test_Y.txt")
y_test=(pd.read_csv(y_test, sep="\t",header=0)).iloc[:,1]

# %% [markdown]
# ### using input label

# %%
data_in=x_train
data_real_out=y_train
test_in=x_test
test_real_out=y_test

# %% [markdown]
# ### data normalization

# %%
data_in_max=data_in.max()
data_in_min=data_in.min()
data_in_norm=(data_in-data_in_min)/(data_in_max-data_in_min)
data_in_norm=np.asarray(data_in_norm)

data_real_out_max=data_real_out.max()
data_real_out_min=data_real_out.min()
data_real_out_norm=(data_real_out-data_real_out_min)/(data_real_out_max-data_real_out_min)
data_real_out_norm=np.asarray(data_real_out_norm)

test_in_max=test_in.max()
test_in_min=test_in.min()
test_in_norm=(test_in-test_in_min)/(test_in_max-test_in_min)
test_in_norm=np.asarray(test_in_norm)

test_real_out_max=test_real_out.max()
test_real_out_min=test_real_out.min()
test_real_out_norm=(test_real_out-test_real_out_min)/(test_real_out_max-test_real_out_min)
test_real_out_norm=np.asarray(test_real_out_norm)

# %% [markdown]
# ### Build Model

# %%
#define error function & calculate model's output error
def np_RMSE(output,output_pred):
    rmserror=0
    for i in range(len(output)):
        rmserror=rmserror+np.square(output[i]-output_pred[i])
    rmserror=np.sqrt(rmserror/len(output))
    return rmserror

def np_R2(output,output_pred):
    return np.square(np.corrcoef(output.reshape(np.size(output)),output_pred.reshape(np.size(output_pred)), False)[1,0])

# %% [markdown]
# #### 1-b. 以交叉驗證方式訓練BPNN模式，列初步同分組組合之RMSE與$R^2$值

# %%
from keras.models import Sequential,load_model
from keras import backend as K
from keras.layers import Dense
from keras.layers.core import Activation
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.optimizers import adam_v2
#from keras.layers.normalization import BatchNormalization
from sklearn.model_selection import KFold
from keras.callbacks import History
from keras.metrics import mean_squared_error as mserr

history = History()

RMSE_history_list = []
R2_history_list = []
seed = 7
best_RMSE = np.inf
kfold = KFold(n_splits=3, shuffle=False)
for train, validation in kfold.split(data_in_norm, data_real_out_norm):

    K.clear_session()
    # 模型結構
    model = Sequential()
    model.add(RBFLayer(20,initializer=InitCentersRandom(data_in_norm),betas=1.0,input_shape=(len(data_in_norm[0]),)))
    model.add(Activation('tanh'))
    model.add(Dense(1))

    # 模型相關設定
    learning_rate=1e-4 #設定學習速率
    adam = adam_v2.Adam(lr=learning_rate) #設定的優化器
    model.compile(optimizer=adam,loss="mse") #執行設定好的優化器和誤差函數
    # earlystopper = EarlyStopping(monitor='val_loss', patience=10, verbose=0) #設定early stopping的參數
    # checkpoint =ModelCheckpoint("rbf-model.hdf5",save_best_only=True)
    #每次迭代儲存模式，我設定了最終只儲存最佳的模式(當驗證誤差最小的時候)
    # callback_list=[earlystopper,checkpoint]
    model.fit(data_in_norm,data_real_out_norm,
              epochs=200, batch_size=8, validation_split=0.2, workers=8
              # callbacks=callback_list
              )

    prediction = np.squeeze(model.predict(data_in_norm[validation]))
    current_RMSE = np_RMSE(prediction, data_real_out_norm[validation])
    current_R2 = np_R2(prediction, data_real_out_norm[validation])
    RMSE_history_list.append(current_RMSE)
    R2_history_list.append(current_R2)

    if (current_RMSE < best_RMSE):
        best_RMSE = current_RMSE
        model.save("rbf-model.hdf5")
        print(f'best model updated!')
    #執行模式訓練并且把設定好的early stopping以及儲存模式參數套用到訓練中

#more details reference: https://keras.io/
# Out:
# Epoch 1/200
#  1/50 [..............................] - ETA: 7s - loss: 0.3605
# C:\Users\woody\AppData\Roaming\Python\Python38\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3755 - val_loss: 0.2990
# Epoch 2/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3222 - val_loss: 0.2559
# Epoch 3/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2810 - val_loss: 0.2227
# Epoch 4/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2489 - val_loss: 0.1976
# Epoch 5/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2240 - val_loss: 0.1782
# Epoch 6/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2047 - val_loss: 0.1626
# Epoch 7/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1892 - val_loss: 0.1503
# Epoch 8/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1768 - val_loss: 0.1397
# Epoch 9/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1660 - val_loss: 0.1313
# Epoch 10/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1567 - val_loss: 0.1238
# Epoch 11/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1484 - val_loss: 0.1168
# Epoch 12/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1407 - val_loss: 0.1103
# Epoch 13/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1336 - val_loss: 0.1045
# Epoch 14/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1269 - val_loss: 0.0989
# Epoch 15/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1204 - val_loss: 0.0936
# Epoch 16/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1144 - val_loss: 0.0885
# Epoch 17/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1085 - val_loss: 0.0837
# Epoch 18/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1029 - val_loss: 0.0791
# Epoch 19/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0977 - val_loss: 0.0746
# Epoch 20/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0927 - val_loss: 0.0705
# Epoch 21/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0878 - val_loss: 0.0666
# Epoch 22/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0831 - val_loss: 0.0629
# Epoch 23/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0787 - val_loss: 0.0594
# Epoch 24/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0745 - val_loss: 0.0560
# Epoch 25/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0706 - val_loss: 0.0528
# Epoch 26/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0667 - val_loss: 0.0498
# Epoch 27/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0632 - val_loss: 0.0469
# Epoch 28/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0597 - val_loss: 0.0442
# Epoch 29/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0565 - val_loss: 0.0416
# Epoch 30/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0534 - val_loss: 0.0394
# Epoch 31/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0506 - val_loss: 0.0370
# Epoch 32/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0478 - val_loss: 0.0350
# Epoch 33/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0453 - val_loss: 0.0331
# Epoch 34/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0428 - val_loss: 0.0312
# Epoch 35/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0405 - val_loss: 0.0296
# Epoch 36/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0384 - val_loss: 0.0278
# Epoch 37/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0363 - val_loss: 0.0264
# Epoch 38/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0344 - val_loss: 0.0251
# Epoch 39/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0327 - val_loss: 0.0238
# Epoch 40/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0310 - val_loss: 0.0227
# Epoch 41/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0295 - val_loss: 0.0216
# Epoch 42/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0281 - val_loss: 0.0207
# Epoch 43/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0267 - val_loss: 0.0198
# Epoch 44/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0255 - val_loss: 0.0190
# Epoch 45/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0243 - val_loss: 0.0183
# Epoch 46/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0232 - val_loss: 0.0176
# Epoch 47/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0222 - val_loss: 0.0171
# Epoch 48/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0213 - val_loss: 0.0165
# Epoch 49/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0205 - val_loss: 0.0160
# Epoch 50/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0197 - val_loss: 0.0157
# Epoch 51/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0190 - val_loss: 0.0153
# Epoch 52/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0183 - val_loss: 0.0150
# Epoch 53/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0177 - val_loss: 0.0147
# Epoch 54/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0172 - val_loss: 0.0146
# Epoch 55/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0167 - val_loss: 0.0143
# Epoch 56/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0163 - val_loss: 0.0143
# Epoch 57/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0158 - val_loss: 0.0140
# Epoch 58/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0154 - val_loss: 0.0140
# Epoch 59/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0150 - val_loss: 0.0139
# Epoch 60/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0147 - val_loss: 0.0137
# Epoch 61/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0144 - val_loss: 0.0137
# Epoch 62/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0142 - val_loss: 0.0138
# Epoch 63/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0139 - val_loss: 0.0136
# Epoch 64/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0137 - val_loss: 0.0137
# Epoch 65/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0135 - val_loss: 0.0136
# Epoch 66/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0133 - val_loss: 0.0139
# Epoch 67/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0131 - val_loss: 0.0136
# Epoch 68/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0129 - val_loss: 0.0137
# Epoch 69/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0128 - val_loss: 0.0136
# Epoch 70/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0127 - val_loss: 0.0139
# Epoch 71/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0126 - val_loss: 0.0140
# Epoch 72/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0124 - val_loss: 0.0139
# Epoch 73/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0123 - val_loss: 0.0138
# Epoch 74/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0122 - val_loss: 0.0139
# Epoch 75/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0121 - val_loss: 0.0141
# Epoch 76/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0120 - val_loss: 0.0141
# Epoch 77/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0118 - val_loss: 0.0139
# Epoch 78/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0117 - val_loss: 0.0138
# Epoch 79/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0117 - val_loss: 0.0140
# Epoch 80/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0115 - val_loss: 0.0141
# Epoch 81/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0115 - val_loss: 0.0140
# Epoch 82/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0114 - val_loss: 0.0141
# Epoch 83/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0113 - val_loss: 0.0143
# Epoch 84/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0112 - val_loss: 0.0141
# Epoch 85/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0111 - val_loss: 0.0139
# Epoch 86/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0110 - val_loss: 0.0140
# Epoch 87/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0110 - val_loss: 0.0140
# Epoch 88/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0109 - val_loss: 0.0141
# Epoch 89/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0108 - val_loss: 0.0139
# Epoch 90/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0107 - val_loss: 0.0141
# Epoch 91/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0106 - val_loss: 0.0138
# Epoch 92/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0106 - val_loss: 0.0139
# Epoch 93/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0105 - val_loss: 0.0137
# Epoch 94/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0104 - val_loss: 0.0138
# Epoch 95/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0103 - val_loss: 0.0141
# Epoch 96/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0102 - val_loss: 0.0141
# Epoch 97/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0101 - val_loss: 0.0137
# Epoch 98/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0101 - val_loss: 0.0138
# Epoch 99/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0100 - val_loss: 0.0139
# Epoch 100/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0099 - val_loss: 0.0136
# Epoch 101/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0098 - val_loss: 0.0138
# Epoch 102/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0097 - val_loss: 0.0133
# Epoch 103/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0097 - val_loss: 0.0133
# Epoch 104/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0096 - val_loss: 0.0135
# Epoch 105/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0095 - val_loss: 0.0137
# Epoch 106/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0095 - val_loss: 0.0133
# Epoch 107/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0094 - val_loss: 0.0138
# Epoch 108/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0093 - val_loss: 0.0131
# Epoch 109/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0092 - val_loss: 0.0132
# Epoch 110/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0092 - val_loss: 0.0133
# Epoch 111/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0091 - val_loss: 0.0133
# Epoch 112/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0090 - val_loss: 0.0135
# Epoch 113/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0089 - val_loss: 0.0130
# Epoch 114/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0089 - val_loss: 0.0138
# Epoch 115/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0088 - val_loss: 0.0131
# Epoch 116/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0087 - val_loss: 0.0129
# Epoch 117/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0086 - val_loss: 0.0126
# Epoch 118/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0086 - val_loss: 0.0128
# Epoch 119/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0085 - val_loss: 0.0128
# Epoch 120/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0084 - val_loss: 0.0129
# Epoch 121/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0084 - val_loss: 0.0129
# Epoch 122/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0083 - val_loss: 0.0128
# Epoch 123/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0082 - val_loss: 0.0126
# Epoch 124/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0082 - val_loss: 0.0124
# Epoch 125/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0081 - val_loss: 0.0122
# Epoch 126/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0080 - val_loss: 0.0126
# Epoch 127/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0080 - val_loss: 0.0124
# Epoch 128/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0079 - val_loss: 0.0124
# Epoch 129/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0078 - val_loss: 0.0119
# Epoch 130/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0078 - val_loss: 0.0120
# Epoch 131/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0077 - val_loss: 0.0122
# Epoch 132/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0076 - val_loss: 0.0124
# Epoch 133/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0076 - val_loss: 0.0122
# Epoch 134/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0075 - val_loss: 0.0120
# Epoch 135/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0074 - val_loss: 0.0120
# Epoch 136/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0074 - val_loss: 0.0119
# Epoch 137/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0073 - val_loss: 0.0120
# Epoch 138/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0073 - val_loss: 0.0117
# Epoch 139/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0072 - val_loss: 0.0116
# Epoch 140/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.0112
# Epoch 141/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.0116
# Epoch 142/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0070 - val_loss: 0.0116
# Epoch 143/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0069 - val_loss: 0.0113
# Epoch 144/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0069 - val_loss: 0.0117
# Epoch 145/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0113
# Epoch 146/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0113
# Epoch 147/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.0110
# Epoch 148/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.0111
# Epoch 149/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.0112
# Epoch 150/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.0112
# Epoch 151/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.0109
# Epoch 152/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0112
# Epoch 153/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0105
# Epoch 154/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0106
# Epoch 155/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0107
# Epoch 156/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0106
# Epoch 157/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.0104
# Epoch 158/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.0107
# Epoch 159/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0108
# Epoch 160/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0104
# Epoch 161/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0099
# Epoch 162/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0103
# Epoch 163/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0103
# Epoch 164/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.0100
# Epoch 165/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.0103
# Epoch 166/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.0100
# Epoch 167/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0104
# Epoch 168/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0101
# Epoch 169/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0103
# Epoch 170/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.0098
# Epoch 171/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.0101
# Epoch 172/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.0100
# Epoch 173/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0101
# Epoch 174/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0097
# Epoch 175/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0100
# Epoch 176/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0096
# Epoch 177/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0100
# Epoch 178/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0092
# Epoch 179/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 0.0095
# Epoch 180/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 0.0095
# Epoch 181/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0093
# Epoch 182/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0098
# Epoch 183/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0095
# Epoch 184/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0094
# Epoch 185/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0094
# Epoch 186/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0093
# Epoch 187/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0092
# Epoch 188/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0091
# Epoch 189/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 190/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0096
# Epoch 191/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0045 - val_loss: 0.0093
# Epoch 192/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0045 - val_loss: 0.0087
# Epoch 193/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0091
# Epoch 194/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0088
# Epoch 195/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0091
# Epoch 196/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0092
# Epoch 197/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0087
# Epoch 198/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0090
# Epoch 199/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0042 - val_loss: 0.0084
# Epoch 200/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0042 - val_loss: 0.0084
# best model updated!
# Epoch 1/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.5134 - val_loss: 0.4582
# Epoch 2/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4309 - val_loss: 0.3884
# Epoch 3/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3643 - val_loss: 0.3307
# Epoch 4/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3099 - val_loss: 0.2846
# Epoch 5/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2666 - val_loss: 0.2461
# Epoch 6/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2322 - val_loss: 0.2143
# Epoch 7/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2047 - val_loss: 0.1893
# Epoch 8/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1828 - val_loss: 0.1692
# Epoch 9/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1650 - val_loss: 0.1533
# Epoch 10/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1507 - val_loss: 0.1394
# Epoch 11/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1390 - val_loss: 0.1280
# Epoch 12/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1288 - val_loss: 0.1183
# Epoch 13/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1201 - val_loss: 0.1100
# Epoch 14/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1125 - val_loss: 0.1022
# Epoch 15/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1057 - val_loss: 0.0955
# Epoch 16/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0994 - val_loss: 0.0897
# Epoch 17/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0936 - val_loss: 0.0843
# Epoch 18/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0882 - val_loss: 0.0795
# Epoch 19/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0831 - val_loss: 0.0747
# Epoch 20/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0782 - val_loss: 0.0707
# Epoch 21/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0737 - val_loss: 0.0663
# Epoch 22/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0693 - val_loss: 0.0625
# Epoch 23/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0652 - val_loss: 0.0589
# Epoch 24/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0612 - val_loss: 0.0555
# Epoch 25/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0575 - val_loss: 0.0523
# Epoch 26/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0539 - val_loss: 0.0492
# Epoch 27/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0506 - val_loss: 0.0463
# Epoch 28/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0474 - val_loss: 0.0435
# Epoch 29/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0444 - val_loss: 0.0410
# Epoch 30/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0416 - val_loss: 0.0384
# Epoch 31/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0389 - val_loss: 0.0362
# Epoch 32/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0364 - val_loss: 0.0340
# Epoch 33/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0340 - val_loss: 0.0320
# Epoch 34/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0318 - val_loss: 0.0301
# Epoch 35/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0297 - val_loss: 0.0284
# Epoch 36/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0277 - val_loss: 0.0267
# Epoch 37/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0259 - val_loss: 0.0251
# Epoch 38/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0242 - val_loss: 0.0236
# Epoch 39/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0226 - val_loss: 0.0223
# Epoch 40/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0212 - val_loss: 0.0210
# Epoch 41/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0198 - val_loss: 0.0199
# Epoch 42/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0185 - val_loss: 0.0188
# Epoch 43/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0173 - val_loss: 0.0178
# Epoch 44/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0162 - val_loss: 0.0169
# Epoch 45/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0152 - val_loss: 0.0161
# Epoch 46/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0143 - val_loss: 0.0153
# Epoch 47/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0135 - val_loss: 0.0146
# Epoch 48/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0127 - val_loss: 0.0140
# Epoch 49/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0119 - val_loss: 0.0135
# Epoch 50/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0113 - val_loss: 0.0129
# Epoch 51/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0107 - val_loss: 0.0125
# Epoch 52/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0101 - val_loss: 0.0120
# Epoch 53/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0096 - val_loss: 0.0117
# Epoch 54/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0092 - val_loss: 0.0114
# Epoch 55/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0088 - val_loss: 0.0112
# Epoch 56/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0084 - val_loss: 0.0109
# Epoch 57/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0081 - val_loss: 0.0107
# Epoch 58/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0078 - val_loss: 0.0105
# Epoch 59/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0075 - val_loss: 0.0104
# Epoch 60/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0072 - val_loss: 0.0103
# Epoch 61/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0070 - val_loss: 0.0102
# Epoch 62/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0102
# Epoch 63/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.0101
# Epoch 64/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0101
# Epoch 65/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0102
# Epoch 66/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0100
# Epoch 67/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0101
# Epoch 68/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0100
# Epoch 69/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0103
# Epoch 70/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.0101
# Epoch 71/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0103
# Epoch 72/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0103
# Epoch 73/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.0104
# Epoch 74/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0104
# Epoch 75/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0106
# Epoch 76/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0105
# Epoch 77/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0107
# Epoch 78/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0108
# Epoch 79/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 0.0107
# Epoch 80/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0109
# Epoch 81/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0109
# Epoch 82/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0109
# Epoch 83/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0109
# Epoch 84/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0110
# Epoch 85/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0109
# Epoch 86/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0114
# Epoch 87/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0045 - val_loss: 0.0113
# Epoch 88/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0045 - val_loss: 0.0114
# Epoch 89/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0114
# Epoch 90/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0115
# Epoch 91/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0114
# Epoch 92/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0114
# Epoch 93/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0042 - val_loss: 0.0114
# Epoch 94/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0042 - val_loss: 0.0115
# Epoch 95/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0042 - val_loss: 0.0114
# Epoch 96/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0041 - val_loss: 0.0112
# Epoch 97/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0040 - val_loss: 0.0116
# Epoch 98/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0040 - val_loss: 0.0115
# Epoch 99/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0040 - val_loss: 0.0115
# Epoch 100/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0113
# Epoch 101/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0116
# Epoch 102/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0038 - val_loss: 0.0118
# Epoch 103/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0038 - val_loss: 0.0116
# Epoch 104/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0117
# Epoch 105/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0115
# Epoch 106/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0036 - val_loss: 0.0116
# Epoch 107/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0036 - val_loss: 0.0116
# Epoch 108/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0036 - val_loss: 0.0117
# Epoch 109/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0035 - val_loss: 0.0114
# Epoch 110/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0035 - val_loss: 0.0114
# Epoch 111/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0034 - val_loss: 0.0115
# Epoch 112/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0034 - val_loss: 0.0113
# Epoch 113/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0034 - val_loss: 0.0117
# Epoch 114/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0033 - val_loss: 0.0114
# Epoch 115/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0033 - val_loss: 0.0112
# Epoch 116/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0033 - val_loss: 0.0113
# Epoch 117/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0032 - val_loss: 0.0115
# Epoch 118/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0032 - val_loss: 0.0112
# Epoch 119/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0032 - val_loss: 0.0113
# Epoch 120/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0031 - val_loss: 0.0113
# Epoch 121/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0031 - val_loss: 0.0110
# Epoch 122/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0031 - val_loss: 0.0114
# Epoch 123/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0113
# Epoch 124/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0112
# Epoch 125/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0110
# Epoch 126/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0029 - val_loss: 0.0108
# Epoch 127/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0029 - val_loss: 0.0113
# Epoch 128/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0029 - val_loss: 0.0110
# Epoch 129/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0029 - val_loss: 0.0112
# Epoch 130/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0028 - val_loss: 0.0112
# Epoch 131/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0028 - val_loss: 0.0110
# Epoch 132/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0028 - val_loss: 0.0109
# Epoch 133/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0027 - val_loss: 0.0109
# Epoch 134/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0027 - val_loss: 0.0108
# Epoch 135/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0027 - val_loss: 0.0109
# Epoch 136/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0027 - val_loss: 0.0109
# Epoch 137/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0027 - val_loss: 0.0105
# Epoch 138/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0026 - val_loss: 0.0107
# Epoch 139/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0026 - val_loss: 0.0108
# Epoch 140/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0026 - val_loss: 0.0105
# Epoch 141/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0026 - val_loss: 0.0109
# Epoch 142/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0026 - val_loss: 0.0104
# Epoch 143/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0026 - val_loss: 0.0105
# Epoch 144/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0025 - val_loss: 0.0107
# Epoch 145/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0025 - val_loss: 0.0109
# Epoch 146/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0025 - val_loss: 0.0104
# Epoch 147/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0025 - val_loss: 0.0105
# Epoch 148/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0025 - val_loss: 0.0104
# Epoch 149/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0024 - val_loss: 0.0100
# Epoch 150/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0024 - val_loss: 0.0102
# Epoch 151/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0024 - val_loss: 0.0102
# Epoch 152/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0024 - val_loss: 0.0102
# Epoch 153/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0024 - val_loss: 0.0099
# Epoch 154/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0024 - val_loss: 0.0104
# Epoch 155/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0024 - val_loss: 0.0096
# Epoch 156/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0024 - val_loss: 0.0105
# Epoch 157/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0023 - val_loss: 0.0100
# Epoch 158/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0023 - val_loss: 0.0099
# Epoch 159/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0023 - val_loss: 0.0103
# Epoch 160/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0023 - val_loss: 0.0100
# Epoch 161/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0023 - val_loss: 0.0102
# Epoch 162/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0023 - val_loss: 0.0100
# Epoch 163/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0023 - val_loss: 0.0102
# Epoch 164/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0023 - val_loss: 0.0100
# Epoch 165/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0023 - val_loss: 0.0100
# Epoch 166/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0023 - val_loss: 0.0099
# Epoch 167/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0023 - val_loss: 0.0096
# Epoch 168/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0022 - val_loss: 0.0102
# Epoch 169/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0022 - val_loss: 0.0102
# Epoch 170/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0022 - val_loss: 0.0096
# Epoch 171/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0022 - val_loss: 0.0100
# Epoch 172/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0022 - val_loss: 0.0097
# Epoch 173/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0022 - val_loss: 0.0098
# Epoch 174/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0022 - val_loss: 0.0100
# Epoch 175/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0022 - val_loss: 0.0094
# Epoch 176/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0022 - val_loss: 0.0094
# Epoch 177/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0022 - val_loss: 0.0096
# Epoch 178/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0022 - val_loss: 0.0096
# Epoch 179/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0022 - val_loss: 0.0095
# Epoch 180/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0022 - val_loss: 0.0091
# Epoch 181/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0022 - val_loss: 0.0095
# Epoch 182/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0021 - val_loss: 0.0093
# Epoch 183/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 184/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0021 - val_loss: 0.0094
# Epoch 185/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0021 - val_loss: 0.0095
# Epoch 186/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0021 - val_loss: 0.0095
# Epoch 187/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0021 - val_loss: 0.0090
# Epoch 188/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0021 - val_loss: 0.0091
# Epoch 189/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0021 - val_loss: 0.0094
# Epoch 190/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0021 - val_loss: 0.0090
# Epoch 191/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0021 - val_loss: 0.0088
# Epoch 192/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0021 - val_loss: 0.0092
# Epoch 193/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0021 - val_loss: 0.0089
# Epoch 194/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0021 - val_loss: 0.0091
# Epoch 195/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0021 - val_loss: 0.0091
# Epoch 196/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0021 - val_loss: 0.0092
# Epoch 197/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0021 - val_loss: 0.0093
# Epoch 198/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0021 - val_loss: 0.0090
# Epoch 199/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0021 - val_loss: 0.0092
# Epoch 200/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0021 - val_loss: 0.0091
# best model updated!
# Epoch 1/200
# 50/50 [==============================] - 0s 3ms/step - loss: 1.3421 - val_loss: 0.9696
# Epoch 2/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.1742 - val_loss: 0.8463
# Epoch 3/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.0243 - val_loss: 0.7372
# Epoch 4/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.8908 - val_loss: 0.6404
# Epoch 5/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7725 - val_loss: 0.5548
# Epoch 6/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6675 - val_loss: 0.4808
# Epoch 7/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5754 - val_loss: 0.4149
# Epoch 8/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4947 - val_loss: 0.3580
# Epoch 9/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4242 - val_loss: 0.3092
# Epoch 10/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3636 - val_loss: 0.2668
# Epoch 11/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3112 - val_loss: 0.2308
# Epoch 12/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2665 - val_loss: 0.1999
# Epoch 13/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2285 - val_loss: 0.1739
# Epoch 14/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1962 - val_loss: 0.1524
# Epoch 15/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1693 - val_loss: 0.1343
# Epoch 16/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1467 - val_loss: 0.1191
# Epoch 17/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1279 - val_loss: 0.1069
# Epoch 18/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1124 - val_loss: 0.0965
# Epoch 19/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0995 - val_loss: 0.0882
# Epoch 20/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0888 - val_loss: 0.0814
# Epoch 21/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0802 - val_loss: 0.0755
# Epoch 22/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0728 - val_loss: 0.0708
# Epoch 23/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0669 - val_loss: 0.0668
# Epoch 24/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0619 - val_loss: 0.0634
# Epoch 25/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0577 - val_loss: 0.0604
# Epoch 26/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0541 - val_loss: 0.0579
# Epoch 27/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0511 - val_loss: 0.0556
# Epoch 28/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0484 - val_loss: 0.0535
# Epoch 29/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0460 - val_loss: 0.0517
# Epoch 30/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0438 - val_loss: 0.0499
# Epoch 31/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0419 - val_loss: 0.0482
# Epoch 32/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0400 - val_loss: 0.0466
# Epoch 33/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0383 - val_loss: 0.0450
# Epoch 34/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0367 - val_loss: 0.0435
# Epoch 35/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0352 - val_loss: 0.0421
# Epoch 36/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0338 - val_loss: 0.0408
# Epoch 37/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0324 - val_loss: 0.0394
# Epoch 38/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0311 - val_loss: 0.0381
# Epoch 39/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0299 - val_loss: 0.0368
# Epoch 40/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0287 - val_loss: 0.0356
# Epoch 41/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0275 - val_loss: 0.0344
# Epoch 42/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0265 - val_loss: 0.0333
# Epoch 43/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0254 - val_loss: 0.0322
# Epoch 44/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0244 - val_loss: 0.0311
# Epoch 45/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0235 - val_loss: 0.0301
# Epoch 46/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0226 - val_loss: 0.0292
# Epoch 47/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0218 - val_loss: 0.0282
# Epoch 48/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0210 - val_loss: 0.0273
# Epoch 49/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0202 - val_loss: 0.0265
# Epoch 50/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0195 - val_loss: 0.0257
# Epoch 51/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0189 - val_loss: 0.0249
# Epoch 52/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0182 - val_loss: 0.0242
# Epoch 53/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0176 - val_loss: 0.0235
# Epoch 54/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0171 - val_loss: 0.0228
# Epoch 55/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0166 - val_loss: 0.0222
# Epoch 56/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0161 - val_loss: 0.0216
# Epoch 57/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0156 - val_loss: 0.0211
# Epoch 58/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0152 - val_loss: 0.0205
# Epoch 59/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0148 - val_loss: 0.0200
# Epoch 60/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0144 - val_loss: 0.0195
# Epoch 61/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0141 - val_loss: 0.0191
# Epoch 62/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0137 - val_loss: 0.0186
# Epoch 63/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0134 - val_loss: 0.0182
# Epoch 64/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0132 - val_loss: 0.0179
# Epoch 65/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0129 - val_loss: 0.0176
# Epoch 66/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0127 - val_loss: 0.0172
# Epoch 67/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0124 - val_loss: 0.0169
# Epoch 68/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0122 - val_loss: 0.0166
# Epoch 69/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0120 - val_loss: 0.0163
# Epoch 70/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0119 - val_loss: 0.0161
# Epoch 71/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0117 - val_loss: 0.0159
# Epoch 72/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0115 - val_loss: 0.0157
# Epoch 73/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0114 - val_loss: 0.0154
# Epoch 74/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0112 - val_loss: 0.0152
# Epoch 75/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0111 - val_loss: 0.0151
# Epoch 76/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0110 - val_loss: 0.0149
# Epoch 77/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0109 - val_loss: 0.0148
# Epoch 78/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0108 - val_loss: 0.0146
# Epoch 79/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0107 - val_loss: 0.0145
# Epoch 80/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0106 - val_loss: 0.0145
# Epoch 81/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0105 - val_loss: 0.0143
# Epoch 82/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0104 - val_loss: 0.0142
# Epoch 83/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0103 - val_loss: 0.0142
# Epoch 84/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0102 - val_loss: 0.0140
# Epoch 85/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0101 - val_loss: 0.0139
# Epoch 86/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0101 - val_loss: 0.0139
# Epoch 87/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0100 - val_loss: 0.0137
# Epoch 88/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0099 - val_loss: 0.0137
# Epoch 89/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0098 - val_loss: 0.0137
# Epoch 90/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0097 - val_loss: 0.0137
# Epoch 91/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0097 - val_loss: 0.0136
# Epoch 92/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0096 - val_loss: 0.0136
# Epoch 93/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0095 - val_loss: 0.0134
# Epoch 94/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0094 - val_loss: 0.0134
# Epoch 95/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0094 - val_loss: 0.0134
# Epoch 96/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0093 - val_loss: 0.0133
# Epoch 97/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0092 - val_loss: 0.0133
# Epoch 98/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0091 - val_loss: 0.0132
# Epoch 99/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0091 - val_loss: 0.0133
# Epoch 100/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0090 - val_loss: 0.0130
# Epoch 101/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0089 - val_loss: 0.0130
# Epoch 102/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0088 - val_loss: 0.0131
# Epoch 103/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0088 - val_loss: 0.0131
# Epoch 104/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0087 - val_loss: 0.0130
# Epoch 105/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0086 - val_loss: 0.0130
# Epoch 106/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0085 - val_loss: 0.0128
# Epoch 107/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0085 - val_loss: 0.0128
# Epoch 108/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0084 - val_loss: 0.0129
# Epoch 109/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0083 - val_loss: 0.0129
# Epoch 110/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0082 - val_loss: 0.0127
# Epoch 111/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0082 - val_loss: 0.0127
# Epoch 112/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0081 - val_loss: 0.0128
# Epoch 113/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0080 - val_loss: 0.0126
# Epoch 114/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0080 - val_loss: 0.0127
# Epoch 115/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0079 - val_loss: 0.0126
# Epoch 116/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0078 - val_loss: 0.0126
# Epoch 117/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0077 - val_loss: 0.0124
# Epoch 118/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0077 - val_loss: 0.0124
# Epoch 119/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0076 - val_loss: 0.0122
# Epoch 120/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0075 - val_loss: 0.0123
# Epoch 121/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0075 - val_loss: 0.0124
# Epoch 122/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0074 - val_loss: 0.0123
# Epoch 123/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0073 - val_loss: 0.0120
# Epoch 124/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0072 - val_loss: 0.0122
# Epoch 125/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.0122
# Epoch 126/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0070 - val_loss: 0.0120
# Epoch 127/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0070 - val_loss: 0.0121
# Epoch 128/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0069 - val_loss: 0.0120
# Epoch 129/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0120
# Epoch 130/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0118
# Epoch 131/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.0119
# Epoch 132/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.0119
# Epoch 133/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.0118
# Epoch 134/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.0116
# Epoch 135/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0118
# Epoch 136/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0113
# Epoch 137/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0117
# Epoch 138/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0115
# Epoch 139/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.0114
# Epoch 140/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.0114
# Epoch 141/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0113
# Epoch 142/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0112
# Epoch 143/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0114
# Epoch 144/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0114
# Epoch 145/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.0111
# Epoch 146/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0111
# Epoch 147/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0110
# Epoch 148/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0110
# Epoch 149/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0111
# Epoch 150/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.0109
# Epoch 151/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.0108
# Epoch 152/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0106
# Epoch 153/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0105
# Epoch 154/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0106
# Epoch 155/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0110
# Epoch 156/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 0.0107
# Epoch 157/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 0.0106
# Epoch 158/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0103
# Epoch 159/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0105
# Epoch 160/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0103
# Epoch 161/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0106
# Epoch 162/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0102
# Epoch 163/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0104
# Epoch 164/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0102
# Epoch 165/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0045 - val_loss: 0.0101
# Epoch 166/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0045 - val_loss: 0.0100
# Epoch 167/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0101
# Epoch 168/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0098
# Epoch 169/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0098
# Epoch 170/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0099
# Epoch 171/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0042 - val_loss: 0.0099
# Epoch 172/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0042 - val_loss: 0.0096
# Epoch 173/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0041 - val_loss: 0.0098
# Epoch 174/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0041 - val_loss: 0.0096
# Epoch 175/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0040 - val_loss: 0.0096
# Epoch 176/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0040 - val_loss: 0.0094
# Epoch 177/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0098
# Epoch 178/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0093
# Epoch 179/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0038 - val_loss: 0.0093
# Epoch 180/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0038 - val_loss: 0.0096
# Epoch 181/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0092
# Epoch 182/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0094
# Epoch 183/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0093
# Epoch 184/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0036 - val_loss: 0.0091
# Epoch 185/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0036 - val_loss: 0.0089
# Epoch 186/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0035 - val_loss: 0.0089
# Epoch 187/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0035 - val_loss: 0.0092
# Epoch 188/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0035 - val_loss: 0.0087
# Epoch 189/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0034 - val_loss: 0.0088
# Epoch 190/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0034 - val_loss: 0.0088
# Epoch 191/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0034 - val_loss: 0.0087
# Epoch 192/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0033 - val_loss: 0.0086
# Epoch 193/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0033 - val_loss: 0.0086
# Epoch 194/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0033 - val_loss: 0.0084
# Epoch 195/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0032 - val_loss: 0.0086
# Epoch 196/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0032 - val_loss: 0.0084
# Epoch 197/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0032 - val_loss: 0.0082
# Epoch 198/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0031 - val_loss: 0.0087
# Epoch 199/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0031 - val_loss: 0.0084
# Epoch 200/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0084

# %%
df = pd.DataFrame(list(zip(RMSE_history_list, R2_history_list)),
                  columns=['RMSE', 'R2'])

df
# Out:
#        RMSE        R2
# 0  0.063186  0.956790
# 1  0.045984  0.966198
# 2  0.078095  0.941574

# %%
#model forecasting result
model.summary()
model=load_model("rbf-model.hdf5", custom_objects={'RBFLayer': RBFLayer}) #把儲存好的最佳模式讀入

batch_size=8
pred_train=(model.predict(data_in_norm,batch_size=batch_size))*(data_real_out_max-data_real_out_min)+data_real_out_min #針對訓練資料做預測
pred_test=(model.predict(test_in_norm,batch_size=batch_size))*(test_real_out_max-test_real_out_min)+test_real_out_min #針對測試資料做預測

rmse=[];r2=[];
rmse.append(np_RMSE(np.asarray(data_real_out),pred_train))
rmse.append(np_RMSE(np.asarray(test_real_out),pred_test))
r2.append(np_R2(np.asarray(data_real_out),pred_train))
r2.append(np_R2(np.asarray(test_real_out),pred_test))

rmse=np.asarray(rmse).reshape(1,2)
rmse=pd.DataFrame(rmse,columns=['train','test'])
r2=np.asarray(r2).reshape(1,2)
r2=pd.DataFrame(r2,columns=['train','test'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rbf_layer (RBFLayer)        (None, 20)                120
#
#  activation (Activation)     (None, 20)                0
#
#  dense (Dense)               (None, 1)                 21
#
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Plot

# %%
import matplotlib.pyplot as plot

plot1 = plot.figure(1)
plot.scatter(test_real_out,pred_test)
plot.title("train R2=%s"%r2.iloc[0,0])
plot1 = plot.figure(2)
plot.plot(test_real_out)
plot.plot(pred_test)
plot.title("train RMSE=%s"%rmse.iloc[0,0])
plot1 = plot.figure(3)
plot.scatter(test_real_out,pred_test)
plot.title("test R2=%s"%r2.iloc[0,1])
plot1 = plot.figure(4)
plot.plot(test_real_out)
plot.plot(pred_test)
plot.title("test RMSE=%s"%rmse.iloc[0,1])
# Out:
# Text(0.5, 1.0, 'test RMSE=0.07250893')
